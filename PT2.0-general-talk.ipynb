# %% [markdown]
# # PyTorch 2.0 (abbreviated as PT2) a primer

# %% [markdown]
# ![Screenshot 2023-01-23 at 4.44.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# The entire PT2 stack is build on an IR called FX Graphs. So let us have a look into FXGraphs, and then we shall continue from there.

# %% [markdown]
# # Torch FX

# %% [markdown]
# The FX Graph and its related source codes are available at `torch/fx` directory.

# %% [markdown]
# FX is a toolkit for developers to use to transform nn.Module instances. FX consists of three main components: a `symbolic tracer`, an `intermediate representation`, and `Python code generation`. A demonstration of these components in action:

# %%
import torch
import torch.fx

class MyModule(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.param = torch.nn.Parameter(torch.rand(3, 4))
        self.linear = torch.nn.Linear(4, 5)

    def forward(self, x):
        return torch.topk(torch.sum(self.linear(x + self.linear.weight).relu(), dim=-1), 3)

module = MyModule()

# %% [markdown]
# Symbolic tracing frontend - captures the semantics of the module

# %%
from torch.fx import symbolic_trace
symbolic_traced : torch.fx.GraphModule = symbolic_trace(module)

print(f"{type(symbolic_traced)=}")

print(f"{symbolic_traced = }")
# Out:
# type(symbolic_traced)=<class 'torch.fx.graph_module.GraphModule.__new__.<locals>.GraphModuleImpl'>
# symbolic_traced = MyModule(
#   (linear): Linear(in_features=4, out_features=5, bias=True)
# )

# %% [markdown]
# High-level intermediate representation (IR) - Graph representation

# %%
print(symbolic_traced.graph) # this graph is the FX Graph
# Out:
# graph():
#     %x : [num_users=1] = placeholder[target=x]
#     %linear_weight : [num_users=1] = get_attr[target=linear.weight]
#     %add : [num_users=1] = call_function[target=operator.add](args = (%x, %linear_weight), kwargs = {})
#     %linear : [num_users=1] = call_module[target=linear](args = (%add,), kwargs = {})
#     %relu : [num_users=1] = call_method[target=relu](args = (%linear,), kwargs = {})
#     %sum_1 : [num_users=1] = call_function[target=torch.sum](args = (%relu,), kwargs = {dim: -1})
#     %topk : [num_users=1] = call_function[target=torch.topk](args = (%sum_1, 3), kwargs = {})
#     return topk

# %% [markdown]
# Code generation - valid Python code

# %%
print(symbolic_traced.code)
# Out:
# def forward(self, x):
#     linear_weight = self.linear.weight
#     add = x + linear_weight;  x = linear_weight = None
#     linear = self.linear(add);  add = None
#     relu = linear.relu();  linear = None
#     sum_1 = torch.sum(relu, dim = -1);  relu = None
#     topk = torch.topk(sum_1, 3);  sum_1 = None
#     return topk

# %% [markdown]
# The **symbolic tracer** performs “symbolic execution” of the Python code. It feeds fake values, called Proxies, through the code. Operations on theses Proxies are recorded. More information about symbolic tracing can be found in the `symbolic_trace()` and `Tracer` documentation.

# %% [markdown]
# The **intermediate representation** is the container for the operations that were recorded during symbolic tracing. It consists of a list of **Nodes** that represent function inputs, callsites (to functions, methods, or torch.nn.Module instances), and return values. More information about the IR can be found in the documentation for `Graph`. The IR is the format on which transformations are applied.

# %% [markdown]
# **Python code generation** is what makes FX a Python-to-Python (or Module-to-Module) transformation toolkit. For each Graph IR, we can create valid Python code matching the Graph’s semantics. This functionality is wrapped up in GraphModule, which is a torch.nn.Module instance that holds a Graph as well as a forward method generated from the Graph.

# %% [markdown]
# #### A Quick Primer on Graphs

# %% [markdown]
# Full treatment of the semantics of graphs can be found in the **Graph** documentation, but we are going to cover the basics here. A Graph is a data structure that represents a method on a GraphModule. The information that this requires is:
#
# - What are the inputs to the method?
#
# - What are the operations that run inside the method?
#
# - What is the output (i.e. return) value from the method?
#
# All three of these concepts are represented with `Node` instances. Let’s see what we mean by that with a short example:

# %%
class MyModule(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.param = torch.nn.Parameter(torch.rand(3, 4))
        self.linear = torch.nn.Linear(4, 5)

    def forward(self, x):
        return torch.topk(torch.sum(
            self.linear(x + self.linear.weight).relu(), dim=-1), 3)

m = MyModule()
gm = torch.fx.symbolic_trace(m)

graph = gm.graph

# %%
graph.print_tabular()
# Out:
# opcode         name           target                                                   args                kwargs       meta
# -------------  -------------  -------------------------------------------------------  ------------------  -----------  ----------------------------------------------------------------------------------------------------
# placeholder    x              x                                                        ()                  {}           {}
# get_attr       linear_weight  linear.weight                                            ()                  {}           {}
# call_function  add            <built-in function add>                                  (x, linear_weight)  {}           {}
# call_module    linear         linear                                                   (add,)              {}           {'nn_module_stack': OrderedDict([('linear', ('linear', <class 'torch.nn.modules.linear.Linear'>))])}
# call_method    relu           relu                                                     (linear,)           {}           {}
# call_function  sum_1          <built-in method sum of type object at 0x7f6503e7af20>   (relu,)             {'dim': -1}  {}
# call_function  topk           <built-in method topk of type object at 0x7f6503e7af20>  (sum_1, 3)          {}           {}
# output         output         output                                                   (topk,)             {}           {}

# %%
x = gm.print_readable()
# Out:
# class MyModule(torch.nn.Module):
#     def forward(self, x):
#         # No stacktrace found for following nodes
#         linear_weight = self.linear.weight
#         add = x + linear_weight;  x = linear_weight = None
#         linear = self.linear(add);  add = None
#         relu = linear.relu();  linear = None
#         sum_1 = torch.sum(relu, dim = -1);  relu = None
#         topk = torch.topk(sum_1, 3);  sum_1 = None
#         return topk

# %% [markdown]
# We can use this information to answer the questions we posed above.
#
# - What are the inputs to the method? In FX, method inputs are specified via special `placeholder` nodes. In this case, we have a single placeholder node with a target of `x`, meaning we have a single (non-self) argument named x.
#
# - What are the operations within the method? The `get_attr`, `call_function`, `call_module`, and `call_method` nodes represent the operations in the method. A full treatment of the semantics of all of these can be found in the `Node` documentation.
#
# - What is the return value of the method? The return value in a Graph is specified by a special `output` node.
#
# Given that we now know the basics of how code is represented in FX, we can now explore how we would edit a Graph.

# %% [markdown]
# ### Graph Manipulation

# %% [markdown]
# Direct Graph Manipulation

# %% [markdown]
# One approach to building this new Graph is *to directly manipulate your old one*. To aid in this, we can simply take the `Graph` we obtain from symbolic tracing and modify it. For example, let’s say we desire to replace `torch.add()` calls with `torch.mul()` calls.

# %%
import torch
import torch.fx

# Sample module
class M(torch.nn.Module):
    def forward(self, x, y):
        return torch.add(x, y)

def transform(m: torch.nn.Module,
              tracer_class : type = torch.fx.Tracer) -> torch.nn.Module:
    graph : torch.fx.Graph = tracer_class().trace(m)
    # FX represents its Graph as an ordered list of
    # nodes, so we can iterate through them.
    for node in graph.nodes:
        # Checks if we're calling a function (i.e:
        # torch.add)
        if node.op == 'call_function':
            # The target attribute is the function
            # that call_function calls.
            if node.target == torch.add:
                node.target = torch.mul

    graph.lint() # Does some checks to make sure the
                 # Graph is well-formed.

    return torch.fx.GraphModule(m, graph)

# %% [markdown]
# Example to demonstate how addition changes to multiplication.

# %%
x = torch.tensor([1., 2., 3., 4., 5.], device='cuda')
y = torch.tensor([2.]*5, device='cuda')

m = M()
# this should do addition
print(m(x, y))
# Out:
# tensor([3., 4., 5., 6., 7.], device='cuda:0')

# %%
m_transformed = transform(m)
# this should now multiply
print(m_transformed(x, y))
# Out:
# tensor([ 2.,  4.,  6.,  8., 10.], device='cuda:0')

# %% [markdown]
# We can also do more involved `Graph` rewrites, such as deleting or appending nodes. To aid in these transformations, FX has utility functions for transforming the graph that can be found in the `Graph` documentation. An example of using these APIs to append a `torch.relu()` call can be found below.
#
# **Note: this is just a snippet to show how stuffs can be done. A fully example might be more involved.**
#
# ```python
# # Specifies the insertion point. Any nodes added to the
# # Graph within this scope will be inserted after `node`
# with traced.graph.inserting_after(node):
#     # Insert a new `call_function` node calling `torch.relu`
#     new_node = traced.graph.call_function(
#         torch.relu, args=(node,))
#
#     # We want all places that used the value of `node` to
#     # now use that value after the `relu` call we've added.
#     # We use the `replace_all_uses_with` API to do this.
#     node.replace_all_uses_with(new_node)
# ```

# %% [markdown]
# ### A brief on the Node data structure constituting the FX Graphs

# %% [markdown]
# `class torch.fx.Node(graph, name, op, target, args, kwargs, return_type=None)`
#
# `Node` is the data structure that represents individual operations within a `Graph`. For the most part, Nodes represent callsites to various entities, such as operators, methods, and Modules *(some exceptions include nodes that specify function inputs and outputs)*. Each Node has a function specified by its `op` property. The Node semantics for each value of op are as follows:
#
# - `placeholder` represents a function input. The name attribute specifies the name this value will take on. target is similarly the name of the argument. args holds either:
#     - nothing, or
#     - a single argument denoting the default parameter of the function input.
#
#     `kwargs` is don’t-care. Placeholders correspond to the function parameters (e.g. `x`) in the graph printout.
#
# - `get_attr` retrieves a parameter from the module hierarchy. `name` is similarly the name the result of the fetch is assigned to. `target` is the fully-qualified name of the parameter’s position in the module hierarchy. `args` and `kwargs` are don’t-care
#
# - `call_function` applies a free function to some values. `name` is similarly the name of the value to assign to. `target` is the function to be applied. `args` and `kwargs` represent the arguments to the function, following the Python calling convention
#
# - `call_module` applies a module in the module hierarchy’s `forward()` method to given arguments. `name` is as previous. `target` is the fully-qualified name of the module in the module hierarchy to call. `args` and `kwargs` represent the arguments to invoke the module on, excluding the self argument.
#
# - `call_method` calls a method on a value. `name` is as similar. `target` is the string name of the method to apply to the `self` argument. `args` and `kwargs` represent the arguments to invoke the module on, including the *self argument*.
#
# - `output` contains the output of the traced function in its `args[0]` attribute. This corresponds to the “return” statement in the Graph printout.

# %% [markdown]
# ### The Interpreter Pattern

# %% [markdown]
# A useful code organizational pattern in FX is to loop over all the `Nodes` in a `Graph` and execute them. This can be used for several things including runtime analysis of values flowing through the graph or transformation of the code via retracing with `Proxy`s. For example, suppose we want to run a `GraphModule` and record the `torch.Tensor` shape and dtype properties on the nodes as we see them at runtime. (Some kind of data flow analysis) That might look like:

# %%
import torch
import torch.fx
from torch.fx.node import Node

from typing import Dict

class ShapeProp:
    """
    Shape propagation. This class takes a `GraphModule`.
    Then, its `propagate` method executes the `GraphModule`
    node-by-node with the given arguments. As each operation
    executes, the ShapeProp class stores away the shape and
    element type for the output values of each operation on
    the `shape` and `dtype` attributes of the operation's
    `Node`.
    """
    def __init__(self, mod):
        self.mod = mod
        self.graph = mod.graph
        self.modules = dict(self.mod.named_modules())

    def propagate(self, *args):
        args_iter = iter(args)
        env : Dict[str, Node] = {}

        def load_arg(a):
            return torch.fx.graph.map_arg(a, lambda n: env[n.name])

        def fetch_attr(target : str):
            target_atoms = target.split('.')
            attr_itr = self.mod
            for i, atom in enumerate(target_atoms):
                if not hasattr(attr_itr, atom):
                    raise RuntimeError(f"Node referenced nonexistant target {'.'.join(target_atoms[:i])}")
                attr_itr = getattr(attr_itr, atom)
            return attr_itr

        for node in self.graph.nodes:
            if node.op == 'placeholder':
                result = next(args_iter)
            elif node.op == 'get_attr':
                result = fetch_attr(node.target)
            elif node.op == 'call_function':
                result = node.target(*load_arg(node.args), **load_arg(node.kwargs))
            elif node.op == 'call_method':
                self_obj, *args = load_arg(node.args)
                kwargs = load_arg(node.kwargs)
                result = getattr(self_obj, node.target)(*args, **kwargs)
            elif node.op == 'call_module':
                result = self.modules[node.target](*load_arg(node.args), **load_arg(node.kwargs))

            # This is the only code specific to shape propagation.
            # you can delete this `if` branch and this becomes
            # a generic GraphModule interpreter.
            if isinstance(result, torch.Tensor):
                node.shape = result.shape
                node.dtype = result.dtype

            env[node.name] = result

        # return load_arg(self.graph.result)

# %%
shape_propagator = ShapeProp(m_transformed)

# %%
shape_propagator.propagate(x, y)

# %%
from prettytable import PrettyTable

graph = m_transformed.graph

# Define the table
table = PrettyTable()
table.field_names = ["Op", "Name", "Target", "Args", "Kwargs", "Shape", "DType"]

# Add rows to the table
for node in graph.nodes:
    table.add_row([node.op, node.name, node.target, node.args, node.kwargs, node.shape, node.dtype])
    # print(node.format_node())

# Print the table
print(table)
# Out:
# +---------------+--------+--------------------------------------------------------+--------+--------+-----------------+---------------+
# |       Op      |  Name  |                         Target                         |  Args  | Kwargs |      Shape      |     DType     |
# +---------------+--------+--------------------------------------------------------+--------+--------+-----------------+---------------+
# |  placeholder  |   x    |                           x                            |   ()   |   {}   | torch.Size([5]) | torch.float32 |
# |  placeholder  |   y    |                           y                            |   ()   |   {}   | torch.Size([5]) | torch.float32 |
# | call_function |  add   | <built-in method mul of type object at 0x7f6503e7af20> | (x, y) |   {}   | torch.Size([5]) | torch.float32 |
# |     output    | output |                         output                         | (add,) |   {}   | torch.Size([5]) | torch.float32 |
# +---------------+--------+--------------------------------------------------------+--------+--------+-----------------+---------------+

# %% [markdown]
# ### Limitations of Symbolic Tracing

# %% [markdown]
# FX uses a system of **symbolic tracing** (a.k.a symbolic execution) to capture the semantics of programs in a transformable/analyzable form.
#
# - Symbolic Execution means executing code with “symbolic” values instead of real data
# - These symbolic values record operations performed on them, not their results
# - Used by PyTorch FX to trace computation graphs from Python code
#
#
#
# The system is tracing in that it executes the program (really a `torch.nn.Module` or function) to record operations. It is symbolic in that the data flowing through the program during this execution is not real data, but rather symbols (Proxy in FX parlance).
#
# Although symbolic tracing works for most neural net code, it has some limitations.

# %% [markdown]
# #### Dynamic Control Flow

# %% [markdown]
# The main limitation of symbolic tracing is it does not currently support *dynamic control flow*. That is, loops or if statements where the condition may depend on the input values of the program.

# %% [markdown]
# For example, let’s examine the following program:

# %%
def func_to_trace(x):
    if x.sum() > 0:
        return torch.relu(x)
    else:
        return torch.neg(x)

traced = torch.fx.symbolic_trace(func_to_trace)
# Out:
# ---------------------------------------------------------------------------
# TraceError                                Traceback (most recent call last)
# Cell In[15], line 7
#       4     else:
#       5         return torch.neg(x)
# ----> 7 traced = torch.fx.symbolic_trace(func_to_trace)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_symbolic_trace.py:1221, in symbolic_trace(root, concrete_args)
#    1173 """
#    1174 Symbolic tracing API
#    1175
#    (...)
#    1218     GraphModule: a Module created from the recorded operations from ``root``.
#    1219 """
#    1220 tracer = Tracer()
# -> 1221 graph = tracer.trace(root, concrete_args)
#    1222 name = (
#    1223     root.__class__.__name__ if isinstance(root, torch.nn.Module) else root.__name__
#    1224 )
#    1225 return _make_graph_module(tracer.root, graph, name)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_symbolic_trace.py:821, in Tracer.trace(self, root, concrete_args)
#     814         for module in self._autowrap_search:
#     815             _autowrap_check(
#     816                 patcher, module.__dict__, self._autowrap_function_ids
#     817             )
#     818         self.create_node(
#     819             "output",
#     820             "output",
# --> 821             (self.create_arg(fn(*args)),),
#     822             {},
#     823             type_expr=fn.__annotations__.get("return", None),
#     824         )
#     826     self.submodule_paths = None
#     827 finally:
#
# Cell In[15], line 2, in func_to_trace(x)
#       1 def func_to_trace(x):
# ----> 2     if x.sum() > 0:
#       3         return torch.relu(x)
#       4     else:
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/proxy.py:447, in Proxy.__bool__(self)
#     444             self.tracer.create_proxy('call_function', assert_fn, (self,), {})
#     445             return True
# --> 447 return self.tracer.to_bool(self)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/proxy.py:307, in TracerBase.to_bool(self, obj)
#     300 @compatibility(is_backward_compatible=True)
#     301 def to_bool(self, obj: 'Proxy') -> bool:
#     302     """Called when a proxy object is being converted to a boolean, such as
#     303     when used in control flow.  Normally we don't know what to do because
#     304     we don't know the value of the proxy, but a custom tracer can attach more
#     305     information to the graph node using create_node and can choose to return a value.
#     306     """
# --> 307     raise TraceError('symbolically traced variables cannot be used as inputs to control flow')
#
# TraceError: symbolically traced variables cannot be used as inputs to control flow

# %% [markdown]
# On the other hand, so-called *static control flow* is supported. Static control flow is loops or if statements *whose value cannot change across invocations*. Typically, in PyTorch programs, *this control flow arises for code making decisions about a model’s architecture based on hyper-parameters*. As a concrete example:

# %%
import torch
import torch.fx

class MyModule(torch.nn.Module):
    def __init__(self, do_activation : bool = False):
        super().__init__()
        self.do_activation = do_activation
        self.linear = torch.nn.Linear(512, 512)

    def forward(self, x):
        x = self.linear(x)
        # This if-statement is so-called static control flow.
        # Its condition does not depend on any input values
        if self.do_activation:
            x = torch.relu(x)
        return x

without_activation = MyModule(do_activation=False)
with_activation = MyModule(do_activation=True)

# %%
traced_without_activation = torch.fx.symbolic_trace(without_activation)
print(traced_without_activation.code)
# Out:
# def forward(self, x):
#     linear = self.linear(x);  x = None
#     return linear

# %%
traced_with_activation = torch.fx.symbolic_trace(with_activation)
print(traced_with_activation.code)
# Out:
# def forward(self, x):
#     linear = self.linear(x);  x = None
#     relu = torch.relu(linear);  linear = None
#     return relu

# %% [markdown]
# ### Non-Torch Functions

# %% [markdown]
# FX uses `__torch_function__` as the mechanism by which it intercepts calls (see the technical overview for more information about this). Some functions, such as builtin Python functions or those in the math module, are not covered by `__torch_function__`, but we would still like to capture them in symbolic tracing. For example:

# %%
import torch
import torch.fx
from math import sqrt

def normalize(x):
    """
    Normalize `x` by the size of the batch dimension
    """
    return x / sqrt(len(x))

# It's valid Python code
normalize(torch.rand(3, 4))
# Out:
# tensor([[0.2276, 0.1330, 0.5056, 0.1740],
#         [0.0497, 0.2073, 0.0205, 0.5752],
#         [0.5148, 0.5060, 0.2562, 0.3893]])

# %%
traced = torch.fx.symbolic_trace(normalize)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 traced = torch.fx.symbolic_trace(normalize)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_symbolic_trace.py:1221, in symbolic_trace(root, concrete_args)
#    1173 """
#    1174 Symbolic tracing API
#    1175
#    (...)
#    1218     GraphModule: a Module created from the recorded operations from ``root``.
#    1219 """
#    1220 tracer = Tracer()
# -> 1221 graph = tracer.trace(root, concrete_args)
#    1222 name = (
#    1223     root.__class__.__name__ if isinstance(root, torch.nn.Module) else root.__name__
#    1224 )
#    1225 return _make_graph_module(tracer.root, graph, name)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_symbolic_trace.py:821, in Tracer.trace(self, root, concrete_args)
#     814         for module in self._autowrap_search:
#     815             _autowrap_check(
#     816                 patcher, module.__dict__, self._autowrap_function_ids
#     817             )
#     818         self.create_node(
#     819             "output",
#     820             "output",
# --> 821             (self.create_arg(fn(*args)),),
#     822             {},
#     823             type_expr=fn.__annotations__.get("return", None),
#     824         )
#     826     self.submodule_paths = None
#     827 finally:
#
# Cell In[19], line 9, in normalize(x)
#       5 def normalize(x):
#       6     """
#       7     Normalize `x` by the size of the batch dimension
#       8     """
# ----> 9     return x / sqrt(len(x))
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/proxy.py:454, in Proxy.__len__(self)
#     453 def __len__(self):
# --> 454     raise RuntimeError("'len' is not supported in symbolic tracing by default. If you want "
#     455                        "this call to be recorded, please call torch.fx.wrap('len') at "
#     456                        "module scope")
#
# RuntimeError: 'len' is not supported in symbolic tracing by default. If you want this call to be recorded, please call torch.fx.wrap('len') at module scope

# %% [markdown]
# The error tells us that the built-in function `len` is not supported. We can make it so that functions like this are recorded in the trace as direct calls using the `wrap()` API:

# %%
torch.fx.wrap('len')
torch.fx.wrap('sqrt')

traced = torch.fx.symbolic_trace(normalize)

print(traced.code)
# Out:
# torch.fx._symbolic_trace.wrap("len")
# torch.fx._symbolic_trace.wrap("math_sqrt")
#
# def forward(self, x):
#     len_1 = len(x)
#     sqrt = math_sqrt(len_1);  len_1 = None
#     truediv = x / sqrt;  x = sqrt = None
#     return truediv

# %% [markdown]
# There are ways using which you can say FX Tracer to not trace a module like certain non_torch modules and then place the code as it is.

# %% [markdown]
# # TorchDynamo Deep Dive

# %% [markdown]
# **TorchDynamo** is a Python-level Just-In-Time (JIT) compiler designed to make unmodified PyTorch programs faster. TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python bytecode right before it is executed. It rewrites Python bytecode to extract sequences of PyTorch operations into an FX Graph which is then compiled with a customizable backend. It creates this FX Graph through bytecode analysis and is designed to mix Python execution with compiled backends to get the best of both worlds — usability and performance.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Ideally we would like to get a graph/IR representation out of the python program which we write. But static analysis of python code is very difficult.
#
# ![image-2.png](attachment:image-2.png)
#
# The approach which they use is through a new CPython API which was made available in the Python Enhancement Proposal 523. That API is called PythonEvalFrame.
#
# This is how it works:
# - Basic flow is, the python program in a .py file is parsed by some parser and the corresponding bytecode is produced. (Why this approach, let's not go into the details, but in short to support various python interpreters I guess.)
# - Then we feed in each bytecode into the CPython Interpreter loop.
# - The CPython API dicussed above helps us to intercept in between this submission of bytecode to the Cpython interpreter.
# - Using that CPython API, you can write custom logic to modify bytecode before passing it on the CPython interpreter.
# - Also an important point is, you can modify the byte code to make calls to already compiled object code.

# %% [markdown]
# TorchDynamo makes it easy to experiment with different compiler backends to make PyTorch code faster with a single line decorator `torch._dynamo.optimize()` which is wrapped for convenience by `torch.compile()`
#
# The following diagram demonstrates how PyTorch works with `torch.compile` and without it:
# ![image.png](attachment:image.png)

# %% [markdown]
# RESET IPYNB KERNEL HERE

# %%
import os
os.environ['TORCH_LOGS'] = "+dynamo,guards,bytecode"

# %% [markdown]
# If you are not familiar with Python bytecode, you can add a decompiler hook to decompile the bytecode into human-readable source code. One available tool is depyf.

# %%
import depyf
depyf.install()

# %% [markdown]
# Dynamo is a Front-end. To just demonstrate what is happening in TorchDynamo FrontEnd, we just use a dummy compiler backend, at the Torch IR level. (Things shall get clearer as we move along and look at the PT2 backend integration)

# %%
from typing import List
import torch
from torch import _dynamo as torchdynamo
def my_compiler(gm: torch.fx.GraphModule, example_inputs: List[torch.Tensor]):
    print("my_compiler() called with FX graph:")
    gm.graph.print_tabular()
    return gm.forward  # return a python callable

@torchdynamo.optimize(my_compiler)
def toy_example(a, b):
    x = a / (torch.abs(a) + 1)
    if b.sum() < 0:
        b = b * -1
    return x * b
for _ in range(100):
    toy_example(torch.randn(10), torch.randn(10))
# Out:
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0] torchdynamo start compiling toy_example /tmp/ipykernel_711767/4154601551.py:9, stack (elided 6 frames):
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     return _run_code(code, main_globals, None,
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     exec(code, run_globals)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     app.launch_new_instance()
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     app.start()
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     self.io_loop.start()
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     self.asyncio_loop.run_forever()
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     self._run_once()
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     handle._run()
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     self._context.run(self._callback, *self._args)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     await self.process_one()
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     await dispatch(*args)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     await result
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     await super().execute_request(stream, ident, parent)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     reply_content = await reply_content
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     res = shell.run_cell(
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     return super().run_cell(*args, **kwargs)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     result = self._run_cell(
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     result = runner(coro)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     coro.send(None)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     if await self.run_code(code, result, async_=asy):
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     exec(code_obj, self.user_global_ns, self.user_ns)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/tmp/ipykernel_711767/4154601551.py", line 16, in <module>
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     toy_example(torch.randn(10), torch.randn(10))
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 421, in _fn
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     return fn(*args, **kwargs)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py", line 1077, in catch_errors
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]     return callback(frame, cache_entry, hooks, frame_state, skip=1)
# V0613 01:59:47.233000 140497701302272 torch/_dynamo/convert_frame.py:758] [0/0]
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode] ORIGINAL BYTECODE toy_example /tmp/ipykernel_711767/4154601551.py line 9
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]  11           0 LOAD_FAST                0 (a)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               2 LOAD_GLOBAL              0 (torch)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               4 LOAD_METHOD              1 (abs)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               6 LOAD_FAST                0 (a)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               8 CALL_METHOD              1
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              10 LOAD_CONST               1 (1)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              12 BINARY_ADD
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              14 BINARY_TRUE_DIVIDE
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              16 STORE_FAST               2 (x)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]  12          18 LOAD_FAST                1 (b)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              20 LOAD_METHOD              2 (sum)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              22 CALL_METHOD              0
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              24 LOAD_CONST               2 (0)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              26 COMPARE_OP               0 (<)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              28 POP_JUMP_IF_FALSE       19 (to 38)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]  13          30 LOAD_FAST                1 (b)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              32 LOAD_CONST               3 (-1)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              34 BINARY_MULTIPLY
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              36 STORE_FAST               1 (b)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]  14     >>   38 LOAD_FAST                2 (x)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              40 LOAD_FAST                1 (b)
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              42 BINARY_MULTIPLY
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              44 RETURN_VALUE
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# V0613 01:59:47.234000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# I0613 01:59:47.270000 140497701302272 torch/_dynamo/logging.py:55] [0/0] Step 1: torchdynamo start tracing toy_example /tmp/ipykernel_711767/4154601551.py:9
# V0613 01:59:47.272000 140497701302272 torch/fx/experimental/symbolic_shapes.py:2530] [0/0] create_env
# V0613 01:59:47.294000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [0/0] [__trace_source] TRACE starts_line /tmp/ipykernel_711767/4154601551.py:11 in toy_example
# V0613 01:59:47.294000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [0/0] [__trace_source]         x = a / (torch.abs(a) + 1)
# V0613 01:59:47.294000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_FAST a []
# V0613 01:59:47.295000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_GLOBAL torch [LazyVariableTracker()]
# V0613 01:59:47.297000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_ATTR abs [LazyVariableTracker(), PythonModuleVariable(<module 'torch' from '/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/__init__.py'>)]
# V0613 01:59:47.298000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_FAST a [LazyVariableTracker(), TorchInGraphFunctionVariable(<built-in method abs of type object at 0x7fc80667af20>)]
# V0613 01:59:47.298000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [LazyVariableTracker(), TorchInGraphFunctionVariable(<built-in method abs of type object at 0x7fc80667af20>), LazyVariableTracker()]
# V0613 01:59:47.299000 140497701302272 torch/_dynamo/output_graph.py:2029] [0/0] create_graph_input L_a_ L['a']
# V0613 01:59:47.300000 140497701302272 torch/_dynamo/variables/builder.py:2277] [0/0] wrap_to_fake L['a'] (10,) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.STATIC: 2>], constraint_sizes=[None], view_base_context=None, tensor_source=LocalSource(local_name='a', cell_or_freevar=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0613 01:59:47.303000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_CONST 1 [LazyVariableTracker(), TensorVariable()]
# V0613 01:59:47.303000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE BINARY_ADD None [LazyVariableTracker(), TensorVariable(), ConstantVariable()]
# V0613 01:59:47.305000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE BINARY_TRUE_DIVIDE None [LazyVariableTracker(), TensorVariable()]
# V0613 01:59:47.307000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE STORE_FAST x [TensorVariable()]
# V0613 01:59:47.308000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [0/0] [__trace_source] TRACE starts_line /tmp/ipykernel_711767/4154601551.py:12 in toy_example
# V0613 01:59:47.308000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [0/0] [__trace_source]         if b.sum() < 0:
# V0613 01:59:47.308000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_FAST b []
# V0613 01:59:47.308000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_ATTR sum [LazyVariableTracker()]
# V0613 01:59:47.309000 140497701302272 torch/_dynamo/output_graph.py:2029] [0/0] create_graph_input L_b_ L['b']
# V0613 01:59:47.309000 140497701302272 torch/_dynamo/variables/builder.py:2277] [0/0] wrap_to_fake L['b'] (10,) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.STATIC: 2>], constraint_sizes=[None], view_base_context=None, tensor_source=LocalSource(local_name='b', cell_or_freevar=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0613 01:59:47.310000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE CALL_FUNCTION 0 [GetAttrVariable()]
# V0613 01:59:47.312000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_CONST 0 [TensorVariable()]
# V0613 01:59:47.313000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE COMPARE_OP < [TensorVariable(), ConstantVariable()]
# V0613 01:59:47.315000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE POP_JUMP_IF_FALSE 38 [TensorVariable()]
# V0613 01:59:47.315000 140497701302272 torch/_dynamo/symbolic_convert.py:320] [0/0] generic_jump triggered compile
# V0613 01:59:47.316000 140497701302272 torch/_dynamo/output_graph.py:971] [0/0] COMPILING GRAPH due to GraphCompileReason(reason='generic_jump TensorVariable()', user_stack=[<FrameSummary file /tmp/ipykernel_711767/4154601551.py, line 12 in toy_example>], graph_break=True)
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code] TRACED GRAPH
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]  ===== __compiled_fn_1 =====
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]  /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]     def forward(self, L_a_: "f32[10]", L_b_: "f32[10]"):
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         l_a_ = L_a_
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         l_b_ = L_b_
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         # File: /tmp/ipykernel_711767/4154601551.py:11 in toy_example, code: x = a / (torch.abs(a) + 1)
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         abs_1: "f32[10]" = torch.abs(l_a_)
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         add: "f32[10]" = abs_1 + 1;  abs_1 = None
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         x: "f32[10]" = l_a_ / add;  l_a_ = add = None
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         # File: /tmp/ipykernel_711767/4154601551.py:12 in toy_example, code: if b.sum() < 0:
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         sum_1: "f32[]" = l_b_.sum();  l_b_ = None
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         lt: "b8[]" = sum_1 < 0;  sum_1 = None
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         return (x, lt)
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]
# V0613 01:59:47.318000 140497701302272 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]
# I0613 01:59:47.320000 140497701302272 torch/_dynamo/logging.py:55] [0/0] Step 2: calling compiler function my_compiler
# I0613 01:59:47.327000 140497701302272 torch/_dynamo/logging.py:55] [0/0] Step 2: done compiler function my_compiler
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode] MODIFIED BYTECODE toy_example /tmp/ipykernel_711767/4154601551.py line 9
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]   9           0 LOAD_GLOBAL              3 (__compiled_fn_1)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               2 LOAD_FAST                0 (a)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               4 LOAD_FAST                1 (b)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               6 CALL_FUNCTION            2
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               8 UNPACK_SEQUENCE          2
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              10 STORE_FAST               2 (x)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              12 POP_JUMP_IF_FALSE       12 (to 24)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              14 LOAD_GLOBAL              4 (__resume_at_30_2)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              16 LOAD_FAST                1 (b)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              18 LOAD_FAST                2 (x)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              20 CALL_FUNCTION            2
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              22 RETURN_VALUE
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]         >>   24 LOAD_GLOBAL              5 (__resume_at_38_3)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              26 LOAD_FAST                1 (b)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              28 LOAD_FAST                2 (x)
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              30 CALL_FUNCTION            2
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              32 RETURN_VALUE
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# V0613 01:59:47.330000 140497701302272 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:15] [0/0] [__bytecode] possible source code:
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:16] [0/0] [__bytecode] def toy_example(a, b):
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:16] [0/0] [__bytecode]     __temp_2, __temp_3 = __compiled_fn_1(a, b)
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:16] [0/0] [__bytecode]     x = __temp_2
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:16] [0/0] [__bytecode]     if __temp_3:
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:16] [0/0] [__bytecode]         return __resume_at_30_2(b, x)
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:16] [0/0] [__bytecode]     return __resume_at_38_3(b, x)
# V0613 01:59:47.332000 140497701302272 depyf/explain/enhance_logging.py:16] [0/0] [__bytecode]
# V0613 01:59:47.333000 140497701302272 depyf/explain/enhance_logging.py:20] [0/0] [__bytecode] If you find the decompiled code is wrong,please submit an issue at https://github.com/thuml/depyf/issues.
# I0613 01:59:47.335000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3633] [0/0] produce_guards
# V0613 01:59:47.336000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3815] [0/0] track_symint L['a'].size()[0] 10 None
# V0613 01:59:47.336000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3815] [0/0] track_symint L['a'].stride()[0] 1 None
# V0613 01:59:47.336000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3815] [0/0] track_symint L['a'].storage_offset() 0 None
# V0613 01:59:47.337000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3815] [0/0] track_symint L['b'].size()[0] 10 None
# V0613 01:59:47.337000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3815] [0/0] track_symint L['b'].stride()[0] 1 None
# V0613 01:59:47.337000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3815] [0/0] track_symint L['b'].storage_offset() 0 None
# V0613 01:59:47.338000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3979] [0/0] Skipping guard L['a'].size()[0] == 10
# V0613 01:59:47.338000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3979] [0/0] Skipping guard L['a'].stride()[0] == 1
# V0613 01:59:47.339000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3979] [0/0] Skipping guard L['a'].storage_offset() == 0
# V0613 01:59:47.339000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3979] [0/0] Skipping guard L['b'].size()[0] == 10
# V0613 01:59:47.340000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3979] [0/0] Skipping guard L['b'].stride()[0] == 1
# V0613 01:59:47.340000 140497701302272 torch/fx/experimental/symbolic_shapes.py:3979] [0/0] Skipping guard L['b'].storage_offset() == 0
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2172] [0/0] [__guards] GUARDS:
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards]
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] TREE_GUARD_MANAGER:
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] +- RootGuardManager
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- DEFAULT_DEVICE: utils_device.CURRENT_DEVICE == None                           # _dynamo/output_graph.py:459 in init_ambient_guards
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GLOBAL_STATE: ___check_global_state()
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GuardManager: source=L['a'], accessed_by=DictGetItemGuardAccessor(a)
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- TENSOR_MATCH: check_tensor(L['a'], Tensor, DispatchKeySet(CPU, BackendSelect, ADInplaceOrView, AutogradCPU), torch.float32, device=None, requires_grad=False, size=[10], stride=[1])  # x = a / (torch.abs(a) + 1)  # mp/ipykernel_711767/4154601551.py:11 in toy_example
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_HASATTR: hasattr(L['a'], '_dynamo_dynamic_indices') == False           # x = a / (torch.abs(a) + 1)  # mp/ipykernel_711767/4154601551.py:11 in toy_example
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_TENSOR_ALIASING: check_no_aliasing(L['a'], L['b'])
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GuardManager: source=L['b'], accessed_by=DictGetItemGuardAccessor(b)
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- TENSOR_MATCH: check_tensor(L['b'], Tensor, DispatchKeySet(CPU, BackendSelect, ADInplaceOrView, AutogradCPU), torch.float32, device=None, requires_grad=False, size=[10], stride=[1])  # if b.sum() < 0:  # mp/ipykernel_711767/4154601551.py:12 in toy_example
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_HASATTR: hasattr(L['b'], '_dynamo_dynamic_indices') == False           # if b.sum() < 0:  # mp/ipykernel_711767/4154601551.py:12 in toy_example
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_TENSOR_ALIASING: check_no_aliasing(L['a'], L['b'])
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GuardManager: source=G, accessed_by=GlobalsGuardAccessor
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- GuardManager: source=G['torch'], accessed_by=DictGetItemGuardAccessor(torch)
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | | +- ID_MATCH: ___check_obj_id(G['torch'], 140497092130784)                  # x = a / (torch.abs(a) + 1)  # mp/ipykernel_711767/4154601551.py:11 in toy_example
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | | +- GuardManager: source=G['torch'].abs, accessed_by=GetAttrGuardAccessor(abs)
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | | | +- ID_MATCH: ___check_obj_id(G['torch'].abs, 140497092722528)              # x = a / (torch.abs(a) + 1)  # mp/ipykernel_711767/4154601551.py:11 in toy_example
# V0613 01:59:47.341000 140497701302272 torch/_dynamo/guards.py:2151] [0/0] [__guards]
# V0613 01:59:47.342000 140497701302272 torch/_dynamo/convert_frame.py:1047] skipping: _fn (reason: in skipfiles, file: /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0] torchdynamo start compiling torch_dynamo_resume_in_toy_example_at_12 /tmp/ipykernel_711767/4154601551.py:12, stack (elided 6 frames):
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     return _run_code(code, main_globals, None,
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     exec(code, run_globals)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     app.launch_new_instance()
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     app.start()
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     self.io_loop.start()
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     self.asyncio_loop.run_forever()
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     self._run_once()
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     handle._run()
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     self._context.run(self._callback, *self._args)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     await self.process_one()
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     await dispatch(*args)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     await result
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     await super().execute_request(stream, ident, parent)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     reply_content = await reply_content
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     res = shell.run_cell(
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     return super().run_cell(*args, **kwargs)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     result = self._run_cell(
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     result = runner(coro)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     coro.send(None)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     if await self.run_code(code, result, async_=asy):
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     exec(code_obj, self.user_global_ns, self.user_ns)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/tmp/ipykernel_711767/4154601551.py", line 16, in <module>
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     toy_example(torch.randn(10), torch.randn(10))
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 421, in _fn
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     return fn(*args, **kwargs)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/tmp/ipykernel_711767/4154601551.py", line 9, in toy_example
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     @torchdynamo.optimize(my_compiler)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py", line 1077, in catch_errors
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]     return callback(frame, cache_entry, hooks, frame_state, skip=1)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:758] [1/0]
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode] ORIGINAL BYTECODE torch_dynamo_resume_in_toy_example_at_12 /tmp/ipykernel_711767/4154601551.py line 12
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]  12           0 JUMP_ABSOLUTE           16 (to 32)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]               2 LOAD_FAST                2 (a)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]               4 LOAD_GLOBAL              0 (torch)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]               6 LOAD_ATTR                1 (abs)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]               8 LOAD_FAST                2 (a)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              10 CALL_FUNCTION            1
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              12 LOAD_CONST               1 (1)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              14 BINARY_ADD
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              16 BINARY_TRUE_DIVIDE
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              18 STORE_FAST               1 (x)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              20 LOAD_FAST                0 (b)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              22 LOAD_ATTR                2 (sum)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              24 CALL_FUNCTION            0
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              26 LOAD_CONST               2 (0)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              28 COMPARE_OP               0 (<)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              30 POP_JUMP_IF_FALSE       20 (to 40)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]  13     >>   32 LOAD_FAST                0 (b)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              34 LOAD_CONST               3 (-1)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              36 BINARY_MULTIPLY
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              38 STORE_FAST               0 (b)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]  14     >>   40 LOAD_FAST                1 (x)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              42 LOAD_FAST                0 (b)
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              44 BINARY_MULTIPLY
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]              46 RETURN_VALUE
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]
# V0613 01:59:47.345000 140497701302272 torch/_dynamo/convert_frame.py:603] [1/0] [__bytecode]
# I0613 01:59:47.346000 140497701302272 torch/_dynamo/logging.py:55] [1/0] Step 1: torchdynamo start tracing torch_dynamo_resume_in_toy_example_at_12 /tmp/ipykernel_711767/4154601551.py:12
# V0613 01:59:47.346000 140497701302272 torch/fx/experimental/symbolic_shapes.py:2530] [1/0] create_env
# V0613 01:59:47.348000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [1/0] [__trace_source] TRACE starts_line /tmp/ipykernel_711767/4154601551.py:12 in torch_dynamo_resume_in_toy_example_at_12
# V0613 01:59:47.348000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [1/0] [__trace_source]         if b.sum() < 0:
# V0613 01:59:47.348000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE JUMP_ABSOLUTE 32 []
# V0613 01:59:47.348000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [1/0] [__trace_source] TRACE starts_line /tmp/ipykernel_711767/4154601551.py:13 in torch_dynamo_resume_in_toy_example_at_12
# V0613 01:59:47.348000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [1/0] [__trace_source]             b = b * -1
# V0613 01:59:47.349000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE LOAD_FAST b []
# V0613 01:59:47.349000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE LOAD_CONST -1 [LazyVariableTracker()]
# V0613 01:59:47.350000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE BINARY_MULTIPLY None [LazyVariableTracker(), ConstantVariable()]
# V0613 01:59:47.350000 140497701302272 torch/_dynamo/output_graph.py:2029] [1/0] create_graph_input L_b_ L['b']
# V0613 01:59:47.351000 140497701302272 torch/_dynamo/variables/builder.py:2277] [1/0] wrap_to_fake L['b'] (10,) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.STATIC: 2>], constraint_sizes=[None], view_base_context=None, tensor_source=LocalSource(local_name='b', cell_or_freevar=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0613 01:59:47.353000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE STORE_FAST b [TensorVariable()]
# V0613 01:59:47.353000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [1/0] [__trace_source] TRACE starts_line /tmp/ipykernel_711767/4154601551.py:14 in torch_dynamo_resume_in_toy_example_at_12
# V0613 01:59:47.353000 140497701302272 torch/_dynamo/symbolic_convert.py:771] [1/0] [__trace_source]         return x * b
# V0613 01:59:47.354000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE LOAD_FAST x []
# V0613 01:59:47.354000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE LOAD_FAST b [LazyVariableTracker()]
# V0613 01:59:47.355000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE BINARY_MULTIPLY None [LazyVariableTracker(), TensorVariable()]
# V0613 01:59:47.355000 140497701302272 torch/_dynamo/output_graph.py:2029] [1/0] create_graph_input L_x_ L['x']
# V0613 01:59:47.356000 140497701302272 torch/_dynamo/variables/builder.py:2277] [1/0] wrap_to_fake L['x'] (10,) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.STATIC: 2>], constraint_sizes=[None], view_base_context=None, tensor_source=LocalSource(local_name='x', cell_or_freevar=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0613 01:59:47.359000 140497701302272 torch/_dynamo/symbolic_convert.py:794] [1/0] [__trace_bytecode] TRACE RETURN_VALUE None [TensorVariable()]
# I0613 01:59:47.359000 140497701302272 torch/_dynamo/logging.py:55] [1/0] Step 1: torchdynamo done tracing torch_dynamo_resume_in_toy_example_at_12 (RETURN_VALUE)
# V0613 01:59:47.360000 140497701302272 torch/_dynamo/symbolic_convert.py:2419] [1/0] RETURN_VALUE triggered compile
# V0613 01:59:47.360000 140497701302272 torch/_dynamo/output_graph.py:971] [1/0] COMPILING GRAPH due to GraphCompileReason(reason='return_value', user_stack=[<FrameSummary file /tmp/ipykernel_711767/4154601551.py, line 14 in torch_dynamo_resume_in_toy_example_at_12>], graph_break=False)
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code] TRACED GRAPH
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code]  ===== __compiled_fn_5 =====
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code]  /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code]     def forward(self, L_b_: "f32[10]", L_x_: "f32[10]"):
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code]         l_b_ = L_b_
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code]         l_x_ = L_x_
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code]
# V0613 01:59:47.361000 140497701302272 torch/_dynamo/output_graph.py:1290] [1/0] [__graph_code]         # File: /tmp/ipykernel_711767/4154601551.py:13 in torch_dynamo_resume_in_toy_example_at_12, code: b = b * -1
# ...
#          1.3055,  0.6647])), kwargs= {}
# _fn(args= (tensor([-0.1443, -1.7042,  0.3716, -1.7420,  0.6306, -0.3670,  1.6421,  0.8852,
#         -0.9552,  0.6891]), tensor([-1.2219,  1.1264,  0.6360, -0.4455,  0.0375,  1.4782, -0.4668,  1.1419,
#         -0.5152,  0.9325])), kwargs= {}
# _fn(args= (tensor([-0.1261, -0.6302,  0.2709, -0.6353,  0.3867, -0.2685,  0.6215,  0.4695,
#         -0.4885,  0.4080]), tensor([-1.2219,  1.1264,  0.6360, -0.4455,  0.0375,  1.4782, -0.4668,  1.1419,
#         -0.5152,  0.9325])), kwargs= {}
# _fn(args= (tensor([ 0.5570,  0.2447, -0.0930,  1.2560, -1.1017, -0.9438,  1.4896, -1.4484,
#          1.4863, -0.7671]), tensor([-2.3312, -1.1300,  0.0558, -0.7903, -0.4719, -0.1783, -0.3601,  0.8886,
#          1.3343,  1.1354])), kwargs= {}
# _fn(args= (tensor([-2.3312, -1.1300,  0.0558, -0.7903, -0.4719, -0.1783, -0.3601,  0.8886,
#          1.3343,  1.1354]), tensor([ 0.3577,  0.1966, -0.0851,  0.5567, -0.5242, -0.4855,  0.5983, -0.5916,
#          0.5978, -0.4341])), kwargs= {}
# _fn(args= (tensor([-0.3221,  1.0886, -1.0447, -1.2396, -0.1769, -0.8458, -1.5404, -1.4141,
#          1.5287, -0.2336]), tensor([ 1.6829, -0.1752,  0.2409,  0.0808,  0.7321, -0.4093,  0.4912, -0.6913,
#         -0.0638,  1.0161])), kwargs= {}
# _fn(args= (tensor([-0.2436,  0.5212, -0.5109, -0.5535, -0.1503, -0.4582, -0.6064, -0.5858,
#          0.6045, -0.1894]), tensor([ 1.6829, -0.1752,  0.2409,  0.0808,  0.7321, -0.4093,  0.4912, -0.6913,
#         -0.0638,  1.0161])), kwargs= {}
# _fn(args= (tensor([-0.2562, -0.5650, -1.3630,  0.3065, -1.9277,  1.8126,  0.6621,  0.7167,
#          0.3135,  1.3457]), tensor([-1.1185,  0.4905,  0.0402, -0.1923, -0.1610, -0.2859,  1.2659, -0.6677,
#         -2.0734,  0.2888])), kwargs= {}
# _fn(args= (tensor([-1.1185,  0.4905,  0.0402, -0.1923, -0.1610, -0.2859,  1.2659, -0.6677,
#         -2.0734,  0.2888]), tensor([-0.2039, -0.3610, -0.5768,  0.2346, -0.6584,  0.6445,  0.3984,  0.4175,
#          0.2387,  0.5737])), kwargs= {}
# _fn(args= (tensor([ 0.5991, -1.5487,  0.0147, -0.4526, -1.0192,  0.0367, -0.7662,  0.7671,
#          0.6747,  0.3655]), tensor([-0.8634,  1.1419,  1.3781, -1.8792,  0.9270, -2.0898, -0.6552, -1.2452,
#          0.8656,  0.3655])), kwargs= {}
# _fn(args= (tensor([-0.8634,  1.1419,  1.3781, -1.8792,  0.9270, -2.0898, -0.6552, -1.2452,
#          0.8656,  0.3655]), tensor([ 0.3746, -0.6076,  0.0145, -0.3116, -0.5048,  0.0354, -0.4338,  0.4341,
#          0.4029,  0.2677])), kwargs= {}
# _fn(args= (tensor([-0.9283,  1.1001,  0.7179,  0.0497, -0.5305,  0.3821,  1.6704,  1.3258,
#          0.4431,  0.3778]), tensor([ 1.4580,  0.2716,  1.8035,  0.6566,  0.6747, -0.8767, -1.7089,  0.5584,
#         -1.6003,  0.9014])), kwargs= {}
# _fn(args= (tensor([-0.4814,  0.5238,  0.4179,  0.0473, -0.3466,  0.2764,  0.6255,  0.5700,
#          0.3071,  0.2742]), tensor([ 1.4580,  0.2716,  1.8035,  0.6566,  0.6747, -0.8767, -1.7089,  0.5584,
#         -1.6003,  0.9014])), kwargs= {}
# _fn(args= (tensor([-0.5918,  1.2901, -0.5821,  0.5754, -0.6994, -0.0516,  1.0453, -0.5646,
#          0.2369, -0.8697]), tensor([ 2.0396, -0.4371, -0.7481, -0.0627, -0.9229, -0.7367,  0.5115,  0.3862,
#         -1.0598,  0.3204])), kwargs= {}
# _fn(args= (tensor([ 2.0396, -0.4371, -0.7481, -0.0627, -0.9229, -0.7367,  0.5115,  0.3862,
#         -1.0598,  0.3204]), tensor([-0.3718,  0.5633, -0.3679,  0.3652, -0.4115, -0.0491,  0.5111, -0.3608,
#          0.1916, -0.4651])), kwargs= {}
# _fn(args= (tensor([-0.9106, -0.5252,  0.6295, -0.2405, -0.6666,  1.2970, -0.7058,  0.6786,
#          0.5184,  1.2921]), tensor([ 0.1563,  0.9966,  0.0717,  1.8351, -0.4723,  0.2529,  0.3466, -0.6124,
#         -0.1435,  0.7662])), kwargs= {}
# _fn(args= (tensor([-0.4766, -0.3443,  0.3863, -0.1939, -0.4000,  0.5646, -0.4138,  0.4043,
#          0.3414,  0.5637]), tensor([ 0.1563,  0.9966,  0.0717,  1.8351, -0.4723,  0.2529,  0.3466, -0.6124,
#         -0.1435,  0.7662])), kwargs= {}
# _fn(args= (tensor([-0.9559,  1.1963, -0.0968, -0.9384,  0.0900, -1.5862, -0.7139, -1.0307,
#          0.3006, -0.0195]), tensor([ 1.6963, -0.6046,  0.7292,  0.6734,  0.1566,  0.3929,  0.9061, -1.3527,
#         -2.0933,  0.0673])), kwargs= {}
# _fn(args= (tensor([-0.4887,  0.5447, -0.0883, -0.4841,  0.0826, -0.6133, -0.4165, -0.5076,
#          0.2311, -0.0191]), tensor([ 1.6963, -0.6046,  0.7292,  0.6734,  0.1566,  0.3929,  0.9061, -1.3527,
#         -2.0933,  0.0673])), kwargs= {}
# _fn(args= (tensor([-1.3210,  0.3747, -0.0509, -0.2284, -1.1968,  1.2068, -1.4834, -0.7011,
#         -0.2502,  0.0708]), tensor([-0.3158,  0.0162,  0.1131,  0.5342, -0.8744,  1.3293, -0.3965,  0.5023,
#         -0.2183, -0.3981])), kwargs= {}
# _fn(args= (tensor([-0.5692,  0.2726, -0.0484, -0.1859, -0.5448,  0.5469, -0.5973, -0.4122,
#         -0.2001,  0.0661]), tensor([-0.3158,  0.0162,  0.1131,  0.5342, -0.8744,  1.3293, -0.3965,  0.5023,
#         -0.2183, -0.3981])), kwargs= {}
# _fn(args= (tensor([ 0.4265,  0.2010, -0.5805,  0.0342, -0.9596,  1.2738, -0.9411, -0.0976,
#         -0.5748,  0.2361]), tensor([-0.3235, -0.4661,  0.4418, -1.5440,  0.0976, -1.2287, -0.1438, -0.1744,
#          0.5216,  0.6265])), kwargs= {}
# _fn(args= (tensor([-0.3235, -0.4661,  0.4418, -1.5440,  0.0976, -1.2287, -0.1438, -0.1744,
#          0.5216,  0.6265]), tensor([ 0.2990,  0.1673, -0.3673,  0.0331, -0.4897,  0.5602, -0.4848, -0.0890,
#         -0.3650,  0.1910])), kwargs= {}
# _fn(args= (tensor([-1.1487,  0.4502,  0.3137, -0.5298, -1.4912, -1.6940, -0.0603,  0.2916,
#          0.4275, -1.5376]), tensor([-0.2670, -0.3613,  2.2864,  0.9675,  0.9030, -1.9860, -0.3808, -0.1564,
#         -0.8197,  1.8792])), kwargs= {}
# _fn(args= (tensor([-0.5346,  0.3104,  0.2388, -0.3463, -0.5986, -0.6288, -0.0569,  0.2258,
#          0.2995, -0.6059]), tensor([-0.2670, -0.3613,  2.2864,  0.9675,  0.9030, -1.9860, -0.3808, -0.1564,
#         -0.8197,  1.8792])), kwargs= {}
# _fn(args= (tensor([ 0.5722, -0.9871,  0.9392,  0.0109,  1.0475,  2.2582, -0.0899,  0.0405,
#          0.5474,  1.1095]), tensor([ 0.2217, -1.1736,  1.2065, -1.2131, -0.0124, -0.2533,  1.2224,  0.7606,
#         -0.5620,  3.0057])), kwargs= {}
# _fn(args= (tensor([ 0.3639, -0.4968,  0.4843,  0.0108,  0.5116,  0.6931, -0.0825,  0.0389,
#          0.3537,  0.5259]), tensor([ 0.2217, -1.1736,  1.2065, -1.2131, -0.0124, -0.2533,  1.2224,  0.7606,
#         -0.5620,  3.0057])), kwargs= {}
# _fn(args= (tensor([ 1.0520,  0.5981, -0.7479,  1.1624,  0.6323, -0.4023, -0.3534, -1.0283,
#          0.7900,  1.0290]), tensor([ 0.0752, -0.2620, -0.9204,  0.5971, -0.1543,  0.3525, -0.7405, -0.0852,
#          0.5160, -0.2408])), kwargs= {}
# _fn(args= (tensor([ 0.0752, -0.2620, -0.9204,  0.5971, -0.1543,  0.3525, -0.7405, -0.0852,
#          0.5160, -0.2408]), tensor([ 0.5127,  0.3743, -0.4279,  0.5375,  0.3874, -0.2869, -0.2611, -0.5070,
#          0.4414,  0.5071])), kwargs= {}
# _fn(args= (tensor([-1.7577, -2.3127, -0.8896,  0.6591, -1.9590,  0.8753, -0.8575, -1.5163,
#          0.3941,  0.4813]), tensor([-1.0914e+00,  1.8303e-02, -1.0019e+00,  1.2508e-03,  1.4754e+00,
#          4.5064e-01,  5.3296e-01, -1.0432e+00,  8.9849e-01,  5.5483e-01])), kwargs= {}
# _fn(args= (tensor([-0.6374, -0.6981, -0.4708,  0.3973, -0.6620,  0.4668, -0.4617, -0.6026,
#          0.2827,  0.3249]), tensor([-1.0914e+00,  1.8303e-02, -1.0019e+00,  1.2508e-03,  1.4754e+00,
#          4.5064e-01,  5.3296e-01, -1.0432e+00,  8.9849e-01,  5.5483e-01])), kwargs= {}
# _fn(args= (tensor([-0.6953,  1.3679,  1.0970,  1.5939, -0.2595,  0.8861, -0.5876,  1.6979,
#          1.0050,  0.2183]), tensor([-0.2848, -0.9183,  0.6409,  1.4509,  0.4666,  0.3738,  0.2443, -0.3399,
#          1.2702, -0.2411])), kwargs= {}
# _fn(args= (tensor([-0.4101,  0.5777,  0.5231,  0.6145, -0.2060,  0.4698, -0.3701,  0.6293,
#          0.5012,  0.1792]), tensor([-0.2848, -0.9183,  0.6409,  1.4509,  0.4666,  0.3738,  0.2443, -0.3399,
#          1.2702, -0.2411])), kwargs= {}
# _fn(args= (tensor([-0.9806,  0.8859, -0.2551,  0.4862,  0.1371, -0.8628,  0.0517,  0.3308,
#          1.3725,  0.9819]), tensor([ 1.2451, -0.2231,  1.3123, -1.3465,  1.8733, -1.2443,  0.2081, -0.1938,
#          1.4837, -1.2697])), kwargs= {}
# _fn(args= (tensor([-0.4951,  0.4697, -0.2032,  0.3271,  0.1206, -0.4632,  0.0492,  0.2486,
#          0.5785,  0.4954]), tensor([ 1.2451, -0.2231,  1.3123, -1.3465,  1.8733, -1.2443,  0.2081, -0.1938,
#          1.4837, -1.2697])), kwargs= {}
# _fn(args= (tensor([ 0.7859,  0.4017,  0.4553, -1.1361, -0.1851,  0.1113,  1.5759,  1.0899,
#          0.1806, -1.1050]), tensor([ 0.7049, -1.2155,  1.1444, -0.4118,  0.3009, -0.5984, -0.1047, -0.4155,
#         -1.1934, -1.1484])), kwargs= {}
# _fn(args= (tensor([ 0.7049, -1.2155,  1.1444, -0.4118,  0.3009, -0.5984, -0.1047, -0.4155,
#         -1.1934, -1.1484]), tensor([ 0.4400,  0.2866,  0.3129, -0.5319, -0.1562,  0.1001,  0.6118,  0.5215,
#          0.1530, -0.5249])), kwargs= {}
# _fn(args= (tensor([ 0.7539,  0.0955, -2.2017,  0.2155, -1.3088,  0.3775, -0.5731, -0.0458,
#          1.3874, -1.6523]), tensor([ 0.3872, -0.6932, -0.3373,  0.6553, -0.5206, -1.0714,  0.2117, -1.0941,
#          1.0763,  0.7052])), kwargs= {}
# _fn(args= (tensor([ 0.3872, -0.6932, -0.3373,  0.6553, -0.5206, -1.0714,  0.2117, -1.0941,
#          1.0763,  0.7052]), tensor([ 0.4299,  0.0872, -0.6877,  0.1773, -0.5669,  0.2741, -0.3643, -0.0438,
#          0.5811, -0.6230])), kwargs= {}
# _fn(args= (tensor([-1.0607,  1.4370, -1.1800,  0.8910, -0.2005,  1.1454, -0.3540,  0.5809,
#          0.4177, -0.7532]), tensor([ 1.5109,  1.4665, -0.0162, -0.7179, -2.5241, -0.3454,  0.4500, -0.3337,
#         -1.6360, -0.8841])), kwargs= {}
# _fn(args= (tensor([ 1.5109,  1.4665, -0.0162, -0.7179, -2.5241, -0.3454,  0.4500, -0.3337,
#         -1.6360, -0.8841]), tensor([-0.5147,  0.5897, -0.5413,  0.4712, -0.1670,  0.5339, -0.2614,  0.3674,
#          0.2946, -0.4296])), kwargs= {}
# _fn(args= (tensor([-0.1643, -0.0641,  0.0605,  0.2189,  0.0479, -0.2563, -1.0617, -0.8646,
#          1.1622,  0.9817]), tensor([-0.1451,  1.0930, -0.1837,  1.0559, -0.6652, -0.4340, -0.0527, -0.3244,
#         -0.5079,  0.7797])), kwargs= {}
# _fn(args= (tensor([-0.1411, -0.0602,  0.0571,  0.1796,  0.0457, -0.2040, -0.5150, -0.4637,
#          0.5375,  0.4954]), tensor([-0.1451,  1.0930, -0.1837,  1.0559, -0.6652, -0.4340, -0.0527, -0.3244,
#         -0.5079,  0.7797])), kwargs= {}
# _fn(args= (tensor([ 0.3327, -0.0159, -0.2240,  0.9559, -1.3820,  0.1097, -0.9510,  0.5992,
#          0.5927,  1.8527]), tensor([ 0.4844,  0.8896, -1.1597, -0.3565,  0.1626, -0.6941, -0.0718,  1.4883,
#         -2.4216,  0.6890])), kwargs= {}
# _fn(args= (tensor([ 0.4844,  0.8896, -1.1597, -0.3565,  0.1626, -0.6941, -0.0718,  1.4883,
#         -2.4216,  0.6890]), tensor([ 0.2496, -0.0157, -0.1830,  0.4887, -0.5802,  0.0988, -0.4874,  0.3747,
#          0.3721,  0.6495])), kwargs= {}
# _fn(args= (tensor([ 0.0259,  0.2307, -0.8257,  0.4126, -0.1857,  0.1429,  0.7187, -0.0394,
#          0.2191,  0.8219]), tensor([-0.2093,  2.2246, -0.1583,  1.2161,  1.6587, -0.1259, -1.8942,  0.4579,
#         -0.2799, -0.7082])), kwargs= {}
# _fn(args= (tensor([ 0.0252,  0.1874, -0.4523,  0.2921, -0.1566,  0.1251,  0.4182, -0.0379,
#          0.1797,  0.4511]), tensor([-0.2093,  2.2246, -0.1583,  1.2161,  1.6587, -0.1259, -1.8942,  0.4579,
#         -0.2799, -0.7082])), kwargs= {}
# _fn(args= (tensor([-1.1168, -0.5325, -0.8731, -0.4545, -0.3861, -0.9858, -2.5565,  0.3671,
#          0.4289,  1.0627]), tensor([-2.8724,  2.7852,  0.7550,  0.1943, -0.2057,  0.1483,  2.0032, -0.4947,
#          0.8422,  0.9229])), kwargs= {}
# _fn(args= (tensor([-0.5276, -0.3475, -0.4661, -0.3125, -0.2786, -0.4964, -0.7188,  0.2685,
#          0.3002,  0.5152]), tensor([-2.8724,  2.7852,  0.7550,  0.1943, -0.2057,  0.1483,  2.0032, -0.4947,
#          0.8422,  0.9229])), kwargs= {}
# _fn(args= (tensor([-0.4694,  2.8096,  0.1381, -0.7873, -0.4080, -0.3495, -0.3349,  0.3103,
#          1.1043, -1.4800]), tensor([-0.1322, -0.0328, -0.3109,  0.2860, -0.0615, -1.4510,  0.1578,  0.0190,
#          0.3297, -0.8486])), kwargs= {}
# _fn(args= (tensor([-0.1322, -0.0328, -0.3109,  0.2860, -0.0615, -1.4510,  0.1578,  0.0190,
#          0.3297, -0.8486]), tensor([-0.3194,  0.7375,  0.1214, -0.4405, -0.2898, -0.2590, -0.2509,  0.2368,
#          0.5248, -0.5968])), kwargs= {}
# _fn(args= (tensor([-1.7448, -0.6144, -0.9016, -1.2729, -0.3415,  1.8522,  1.7956,  0.6218,
#          0.7746,  0.1852]), tensor([ 3.2083,  0.1392, -1.6176,  0.3044, -0.2261,  1.5406,  0.4431,  0.5131,
#          0.0713, -0.9165])), kwargs= {}
# _fn(args= (tensor([-0.6357, -0.3806, -0.4741, -0.5600, -0.2545,  0.6494,  0.6423,  0.3834,
#          0.4365,  0.1563]), tensor([ 3.2083,  0.1392, -1.6176,  0.3044, -0.2261,  1.5406,  0.4431,  0.5131,
#          0.0713, -0.9165])), kwargs= {}
# _fn(args= (tensor([-0.3356,  0.5017,  1.3944,  1.3512,  2.6025, -0.1802, -1.1508, -1.1781,
#          0.9908, -1.1269]), tensor([ 2.2517,  0.4933, -1.2508,  0.8172, -1.2152, -1.7729, -0.9143,  1.3056,
#         -0.3580,  0.0982])), kwargs= {}
# _fn(args= (tensor([ 2.2517,  0.4933, -1.2508,  0.8172, -1.2152, -1.7729, -0.9143,  1.3056,
#         -0.3580,  0.0982]), tensor([-0.2513,  0.3341,  0.5824,  0.5747,  0.7224, -0.1527, -0.5351, -0.5409,
#          0.4977, -0.5298])), kwargs= {}
# _fn(args= (tensor([-0.7020, -1.8869, -0.6566,  0.2378,  0.1945, -0.6737, -0.7623,  1.1572,
#          1.0450, -0.5196]), tensor([-0.3458,  0.6964,  1.0184,  0.5885, -1.7523, -0.1785,  0.1028, -0.0779,
#         -0.3614,  0.7930])), kwargs= {}
# _fn(args= (tensor([-0.4124, -0.6536, -0.3964,  0.1921,  0.1628, -0.4025, -0.4325,  0.5364,
#          0.5110, -0.3419]), tensor([-0.3458,  0.6964,  1.0184,  0.5885, -1.7523, -0.1785,  0.1028, -0.0779,
#         -0.3614,  0.7930])), kwargs= {}

# %% [markdown]
# The original forward method was:
# ```py
# def toy_example(a, b):
#     x = a / (torch.abs(a) + 1)
#     if b.sum() < 0:
#         b = b * -1
#     return x * b
# ```
#
# The debug messages above generated the following  `__compiled_fn_1`
# ```py
#  ===== __compiled_fn_1 =====
#  /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
#     def forward(self, L_a_: "f32[10]", L_b_: "f32[10]"):
#         l_a_ = L_a_
#         l_b_ = L_b_
#
#         # File: /tmp/ipykernel_692535/4154601551.py:11 in toy_example, code: x = a / (torch.abs(a) + 1)
#         abs_1: "f32[10]" = torch.abs(l_a_)
#         add: "f32[10]" = abs_1 + 1;  abs_1 = None
#         x: "f32[10]" = l_a_ / add;  l_a_ = add = None
#
#         # File: /tmp/ipykernel_692535/4154601551.py:12 in toy_example, code: if b.sum() < 0:
#         sum_1: "f32[]" = l_b_.sum();  l_b_ = None
#         lt: "b8[]" = sum_1 < 0;  sum_1 = None
#         return (x, lt)
# ```
#
# Note that FxGraphs cannot deal with dynamic control flows. So Dynamo introduces a FX Graph break at the `if b.sum() < 0:` statment.
# This compiled function basically returns the `x = a / (torch.abs(a)+1)` and `b.sum() < 0` conditional decision as a tuple.

# %% [markdown]
# You might be curious of what happens if we just pass the forward method as shown above through FXGraph Legacy trace? It causes error

# %%
import torch
import torch.fx

def toy_example(a, b):
    x = a / (torch.abs(a) + 1)
    if b.sum() < 0:
        b = b * -1
    return x * b

traced_module = torch.fx.symbolic_trace(toy_example)
print(traced_module)
# Out:
# _fn(args= (<torch.fx._symbolic_trace.Tracer object at 0x7fc72988ca00>, <function toy_example at 0x7fc75054c940>, None), kwargs= {}
# ---------------------------------------------------------------------------
# TraceError                                Traceback (most recent call last)
# Cell In[4], line 10
#       7         b = b * -1
#       8     return x * b
# ---> 10 traced_module = torch.fx.symbolic_trace(toy_example)
#      11 print(traced_module)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_symbolic_trace.py:1221, in symbolic_trace(root, concrete_args)
#    1173 """
#    1174 Symbolic tracing API
#    1175
#    (...)
#    1218     GraphModule: a Module created from the recorded operations from ``root``.
#    1219 """
#    1220 tracer = Tracer()
# -> 1221 graph = tracer.trace(root, concrete_args)
#    1222 name = (
#    1223     root.__class__.__name__ if isinstance(root, torch.nn.Module) else root.__name__
#    1224 )
#    1225 return _make_graph_module(tracer.root, graph, name)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:568, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     559 try:
#     560     # print each element in the args along with its id and type
#     561     # print it in a single line as _fn(args= (args, id of type), args= (args, id of type))
#    (...)
#     565     #     print(f"({arg}, {hex(id(arg))}, {type(arg)}), ", end="")
#     566     # print()
#     567     print(f"_fn(args= {args}, kwargs= {kwargs}")
# --> 568     return fn(*args, **kwargs)
#     569 finally:
#     570     set_eval_frame(prior)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_symbolic_trace.py:821, in Tracer.trace(self, root, concrete_args)
#     814         for module in self._autowrap_search:
#     815             _autowrap_check(
#     816                 patcher, module.__dict__, self._autowrap_function_ids
#     817             )
#     818         self.create_node(
#     819             "output",
#     820             "output",
# --> 821             (self.create_arg(fn(*args)),),
#     822             {},
#     823             type_expr=fn.__annotations__.get("return", None),
#     824         )
#     826     self.submodule_paths = None
#     827 finally:
#
# Cell In[4], line 6, in toy_example(a, b)
#       4 def toy_example(a, b):
#       5     x = a / (torch.abs(a) + 1)
# ----> 6     if b.sum() < 0:
#       7         b = b * -1
#       8     return x * b
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/proxy.py:447, in Proxy.__bool__(self)
#     444             self.tracer.create_proxy('call_function', assert_fn, (self,), {})
#     445             return True
# --> 447 return self.tracer.to_bool(self)
#
# File /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/proxy.py:307, in TracerBase.to_bool(self, obj)
#     300 @compatibility(is_backward_compatible=True)
#     301 def to_bool(self, obj: 'Proxy') -> bool:
#     302     """Called when a proxy object is being converted to a boolean, such as
#     303     when used in control flow.  Normally we don't know what to do because
#     304     we don't know the value of the proxy, but a custom tracer can attach more
#     305     information to the graph node using create_node and can choose to return a value.
#     306     """
# --> 307     raise TraceError('symbolically traced variables cannot be used as inputs to control flow')
#
# TraceError: symbolically traced variables cannot be used as inputs to control flow

# %% [markdown]
# In the above example we also see something as the modified byte code (the corresponding python source code of it by depyf)
# ```py
# # possible source code:
#  def toy_example(a, b):
#      __temp_2, __temp_3 = __compiled_fn_1(a, b)
#      x = __temp_2
#      if __temp_3:
#          return __resume_at_30_2(b, x)
#      return __resume_at_38_3(b, x)
# ```
#
# In the modified bytecode, `__compiled_fn_1` is the return value of `my_compiler()` (the compiled graph). `__resume_at_30_2` and `__resume_at_38_3` are both generated continuation functions that pick up execution after a graph break (at bytecode offsets 30 and 38). Each of these functions take the form:
#
# ```py
# __resume_at_<offset>:
#     ... restore stack state if needed ...
#     JUMP_ABSOLUTE <offset> into toy_example
#     ... original bytecode of toy_example ...
# ```
# By generating this resume_at function, we force the remainder of the function to be executed in a new Python frame which recursively triggers TorchDynamo to restart its capture once execution reaches that point for the first time.

# %% [markdown]
# Let us have a look at the source of the `__resume_at_30_2` and `__resume_at_38_3` function

# %%
print("source code of __resume_at_30_2:")
print(depyf.decompile(__resume_at_30_2))
# Out:
# source code of __resume_at_30_2:
# def torch_dynamo_resume_in_toy_example_at_12(b, x):
#     b = b * -1
#     return x * b

# %%
print("source code of __resume_at_38_3:")
print(depyf.decompile(__resume_at_38_3))
# Out:
# source code of __resume_at_38_3:
# def torch_dynamo_resume_in_toy_example_at_12(b, x):
#     return x * b

# %% [markdown]
# Dynamo restarts its capture for `__resume_at_30_2` and we get a compiled function as:
#
# ```py
#  TRACED GRAPH
#   ===== __compiled_fn_7 =====
#   /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
#      def forward(self, L_b_: "f32[10]", L_x_: "f32[10]"):
#          l_b_ = L_b_
#          l_x_ = L_x_
#
#          # File: /tmp/ipykernel_692535/4154601551.py:13 in torch_dynamo_resume_in_toy_example_at_12, code: b = b * -1
#          b: "f32[10]" = l_b_ * -1;  l_b_ = None
#
#          # File: /tmp/ipykernel_692535/4154601551.py:14 in torch_dynamo_resume_in_toy_example_at_12, code: return x * b
#          mul_1: "f32[10]" = l_x_ * b;  l_x_ = b = None
#          return (mul_1,)
# ```
# And the modified byte code becomes (showing depyf reconstruction):
#
# ```py
# #possible source code:
#  def torch_dynamo_resume_in_toy_example_at_12(b, x):
#      return __compiled_fn_7(b, x)
# ```

# %% [markdown]
# Similarly Dynamo restarts its capture for `__resume_at_38_3` and we get a compiled function as:
#
# ```py
# TRACED GRAPH
# ===== __compiled_fn_5 =====
#   /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
#      def forward(self, L_x_: "f32[10]", L_b_: "f32[10]"):
#          l_x_ = L_x_
#          l_b_ = L_b_
#
#          # File: /tmp/ipykernel_692535/4154601551.py:14 in torch_dynamo_resume_in_toy_example_at_12, code: return x * b
#          mul: "f32[10]" = l_x_ * l_b_;  l_x_ = l_b_ = None
#          return (mul,)
# ```
#
# And the modified byte code becomes (showing depyf reconstruction):
# ```py
# # possible source code:
#  def torch_dynamo_resume_in_toy_example_at_12(b, x):
#      return __compiled_fn_5(x, b)
#
# ```

# %% [markdown]
# ### A brief on Guard

# %% [markdown]
# ```py
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2172] [0/0] [__guards] GUARDS:
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards]
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] TREE_GUARD_MANAGER:
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] +- RootGuardManager
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- DEFAULT_DEVICE: utils_device.CURRENT_DEVICE == None                           # _dynamo/output_graph.py:459 in init_ambient_guards
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GLOBAL_STATE: ___check_global_state()
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GuardManager: source=L['a'], accessed_by=DictGetItemGuardAccessor(a)
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- TENSOR_MATCH: check_tensor(L['a'], Tensor, DispatchKeySet(CPU, BackendSelect, ADInplaceOrView, AutogradCPU), torch.float32, device=None, requires_grad=False, size=[10], stride=[1])  # x = a / (torch.abs(a) + 1)  # mp/ipykernel_692535/4154601551.py:11 in toy_example
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_HASATTR: hasattr(L['a'], '_dynamo_dynamic_indices') == False           # x = a / (torch.abs(a) + 1)  # mp/ipykernel_692535/4154601551.py:11 in toy_example
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_TENSOR_ALIASING: check_no_aliasing(L['a'], L['b'])
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GuardManager: source=L['b'], accessed_by=DictGetItemGuardAccessor(b)
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- TENSOR_MATCH: check_tensor(L['b'], Tensor, DispatchKeySet(CPU, BackendSelect, ADInplaceOrView, AutogradCPU), torch.float32, device=None, requires_grad=False, size=[10], stride=[1])  # if b.sum() < 0:  # mp/ipykernel_692535/4154601551.py:12 in toy_example
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_HASATTR: hasattr(L['b'], '_dynamo_dynamic_indices') == False           # if b.sum() < 0:  # mp/ipykernel_692535/4154601551.py:12 in toy_example
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- NO_TENSOR_ALIASING: check_no_aliasing(L['a'], L['b'])
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | +- GuardManager: source=G, accessed_by=GlobalsGuardAccessor
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | +- GuardManager: source=G['torch'], accessed_by=DictGetItemGuardAccessor(torch)
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | | +- ID_MATCH: ___check_obj_id(G['torch'], 140117675359296)                  # x = a / (torch.abs(a) + 1)  # mp/ipykernel_692535/4154601551.py:11 in toy_example
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | | +- GuardManager: source=G['torch'].abs, accessed_by=GetAttrGuardAccessor(abs)
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards] | | | | +- ID_MATCH: ___check_obj_id(G['torch'].abs, 140117675967408)              # x = a / (torch.abs(a) + 1)  # mp/ipykernel_692535/4154601551.py:11 in toy_example
# V0611 21:51:25.083000 140117874032640 torch/_dynamo/guards.py:2151] [0/0] [__guards]
# ```

# %% [markdown]
# If any of those guards fail, the graph will be recaptured and recompiled. The interesting guard there is `check_tensor`, which checks the following `torch.Tensor` properties:
# - Python class of the tensor (tensor subclassing, etc)
# - dtype
# - device
# - requires_grad
# - dispatch_key (with thread-local includes/excludes applied)
# - ndim
# - sizes*
# - strides*
#
# Argument `L` of the guard function. This is a dict mapping the name of arguments of `toy_example` to its values. This is only available when the function is called, where the frame evaluation API comes into play. In short, `L` is a dict with structure of `{'a': value_a, 'b': value_b}`. Therefore, you can see the code uses `L['a']` to refer to the input variable `a`.

# %% [markdown]
# To summarize, the compiled code is conceptually equivalent to the code below:
#
# ```py
# def compiled_example(a, b):
#     L = {'a': a, 'b': b}
#     for guard, code in get_cache_entries():
#         if guard(L):
#             return code(a, b)
#     recompile_and_add_another_cache_entry()
# ```
# The following diagram demonstrates how torch.compile transforms and optimizes user-written code: it first extracts computation graphs from the user-written function, and compiles these graphs into optimized functions, then assembles them into a new function, which is functionally equivalent to the user-written code but optimized to have a good computation speed.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # PT2 Backend Integration and Torch Inductor Deep Dive

# %% [markdown]
# At a high-level the default options for PyTorch 2.0 deep learning compiler performs the following key tasks:
#
# - **Graph capture**: Computational graph representation for your models and functions.
#     - PyTorch technologies: TorchDynamo, Torch FX, FX IR. (We have dealt with this in the TorchDynamo Section)
# - **Automatic differentiation**: Backward graph tracing using automatic differentiation and lowering to primitives operators.
#     - PyTorch technologies: AOTAutograd, Aten IR
# - **Optimizations**: Forward and backward graph-level optimizations and operator fusion.
#     - PyTorch technologies: TorchInductor (default) or other compilers
# - **Code generation**: Generating hardware specific C++/GPU Code.
#     - PyTorch technologies: TorchInductor, OpenAI Triton (default) other compilers
#
# ![image.png](attachment:image.png)

# %% [markdown]
# For the sake of simplicity, let's define a very simple function and run it through the PT2 stack.
#
# NOTE: You can replace this function with a deep neural network model or an `nn.Module` subclass, but this example should help you appreciate what’s going on under the hood much better than a complex multi-million parameter model.

# %% [markdown]
# RESTART IPYNB NOTEBOOK HERE.

# %%
import torch
import math
import os
import matplotlib.pyplot as plt
import torch._dynamo
from torchvision import models
from torch.fx.passes.graph_drawer import FxGraphDrawer
from IPython.display import Markdown as md

device = torch.device("cuda") if torch.cuda.is_available() else "cpu"

# %%
def f(x):
    return torch.sin(x)**2 + torch.cos(x)**2

md('''
# $ y = f(x) = sin^2(x) + cos^2(x)$
''')
# Out:
# # $ y = f(x) = sin^2(x) + cos^2(x)$

# %% [markdown]
# We take dummy compiler backend named `inspect_backend`. It just needs to follow the protocol, that it takes in a GraphModule (generated by TorchDynamo, basically Torch IR) and sample_inputs.
#
# The function `inspect_backend` if it has to act like a backend compiler, has to call the `return gm.forward` as a part of the protocol.

# %%
def inspect_backend(gm, sample_inputs):
    code = gm.print_readable()
    with open("forward.svg", "wb") as file:
        file.write(FxGraphDrawer(gm,'f').get_dot_graph().create_svg())
    return gm.forward

torch._dynamo.reset()
compiled_f = torch.compile(f, backend=inspect_backend)

x = torch.rand(1000, requires_grad=True).to(device)
out = compiled_f(x)

md(f'''
### Graph
![]({'forward.svg'})
''')
# Out:
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$source=LocalSource(local_name='x', cell_or_freevar=False), type(source)=<class 'torch._dynamo.source.LocalSource'>, source.name()="L['x']"$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# class GraphModule(torch.nn.Module):
#     def forward(self, L_x_: "f32[1000]"):
#         l_x_ = L_x_
#
#         # File: /tmp/ipykernel_711820/1097326487.py:2 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         sin: "f32[1000]" = torch.sin(l_x_)
#         pow_1: "f32[1000]" = sin ** 2;  sin = None
#         cos: "f32[1000]" = torch.cos(l_x_);  l_x_ = None
#         pow_2: "f32[1000]" = cos ** 2;  cos = None
#         add: "f32[1000]" = pow_1 + pow_2;  pow_1 = pow_2 = None
#         return (add,)
#
# type(codegen)=<class 'torch._dynamo.codegen.PyCodegen'>, codegen=<torch._dynamo.codegen.PyCodegen object at 0x7ff9c66b3490>
# type(self.guard_manager)=<class 'torch._dynamo.guards.GuardManager'>
# _fn(args= (tensor([6.5187e-01, 3.4456e-01, 1.9695e-01, 3.8392e-01, 1.9421e-02, 2.9795e-01,
#         7.4800e-01, 4.4737e-01, 6.5262e-01, 4.7996e-01, 8.5593e-02, 1.9033e-01,
#         4.4186e-01, 7.2096e-01, 7.0837e-01, 3.1155e-01, 7.1719e-02, 4.8489e-01,
#         8.6158e-01, 3.7445e-01, 7.2391e-01, 9.9714e-02, 3.2800e-01, 2.3311e-01,
#         9.2540e-01, 4.9103e-02, 2.9470e-01, 4.4161e-01, 8.0872e-01, 6.0282e-01,
#         3.9594e-01, 5.5912e-01, 2.3083e-01, 2.9651e-01, 5.6119e-01, 3.3687e-01,
#         1.0903e-01, 8.7282e-01, 8.0080e-01, 4.8939e-01, 5.3381e-01, 2.6943e-01,
#         6.6509e-01, 3.8339e-01, 3.4165e-01, 5.9020e-01, 1.8927e-01, 6.1859e-01,
#         7.0410e-01, 6.4959e-01, 6.3241e-01, 2.2805e-01, 7.1506e-01, 7.8197e-01,
#         8.4476e-01, 6.4346e-01, 6.4747e-01, 6.5435e-01, 5.8425e-01, 3.2389e-01,
#         3.4935e-01, 7.3256e-01, 9.0206e-01, 9.5869e-01, 8.9217e-01, 5.0056e-01,
#         6.9394e-01, 1.1699e-01, 1.0077e-01, 7.2797e-01, 8.0391e-01, 5.3589e-02,
#         3.5250e-01, 4.8047e-01, 8.0940e-01, 2.7967e-01, 4.6947e-01, 7.0024e-01,
#         9.2133e-01, 7.5874e-01, 4.5855e-01, 9.4518e-01, 5.6963e-01, 1.0474e-01,
#         2.8059e-01, 7.9652e-01, 9.9970e-01, 8.0709e-01, 4.5111e-01, 6.4577e-01,
#         4.1630e-01, 9.6638e-01, 7.1454e-01, 2.0875e-01, 1.7309e-01, 1.6894e-01,
#         4.8730e-01, 5.8953e-01, 4.2404e-01, 3.6396e-01, 1.4442e-01, 8.6661e-01,
#         4.8010e-01, 6.7950e-01, 6.7296e-01, 6.1058e-01, 8.5879e-01, 2.9415e-01,
#         2.7756e-01, 5.1544e-01, 2.8182e-01, 1.1825e-01, 6.0820e-01, 2.7802e-01,
#         9.8232e-01, 4.0139e-01, 9.2945e-01, 1.5612e-02, 4.1204e-01, 8.0126e-01,
#         4.6943e-01, 6.1343e-01, 2.1176e-01, 1.8633e-01, 9.6645e-01, 9.2478e-02,
#         7.1375e-01, 7.1478e-01, 7.0650e-02, 9.7783e-02, 7.2915e-01, 4.7086e-01,
#         4.5286e-01, 7.2781e-01, 6.8272e-01, 3.5753e-01, 7.4198e-01, 1.2134e-01,
#         6.0303e-01, 1.6128e-02, 6.2386e-01, 3.6343e-01, 5.9342e-01, 4.2608e-01,
#         2.9385e-01, 1.0714e-01, 5.0907e-01, 1.9112e-01, 8.6475e-01, 6.8459e-01,
#         7.4480e-01, 8.5414e-01, 2.6017e-01, 4.2414e-01, 4.1350e-01, 7.5219e-03,
#         3.4205e-01, 8.6982e-01, 1.3484e-01, 6.2874e-01, 1.8344e-01, 6.7350e-01,
#         7.4396e-01, 4.1079e-01, 7.5668e-01, 1.4834e-01, 2.5930e-01, 7.7416e-02,
#         7.2855e-01, 8.4122e-01, 3.3662e-01, 2.1495e-01], device='cuda:0',
#        grad_fn=<ToCopyBackward0>),), kwargs= {}
# ### Graph
# ![](forward.svg)

# %% [markdown]
# As we have already seen, but let's recap, the Torch IR received is:
#
# ```py
# class GraphModule(torch.nn.Module):
#     def forward(self, L_x_: "f32[1000]"):
#         l_x_ = L_x_
#
#         # File: /tmp/ipykernel_702509/1097326487.py:2 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         sin: "f32[1000]" = torch.sin(l_x_)
#         pow_1: "f32[1000]" = sin ** 2;  sin = None
#         cos: "f32[1000]" = torch.cos(l_x_);  l_x_ = None
#         pow_2: "f32[1000]" = cos ** 2;  cos = None
#         add: "f32[1000]" = pow_1 + pow_2;  pow_1 = pow_2 = None
#         return (add,)
# ```
#
# And the same if we wanna see graphically, (the above graph annotated with what they do):
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Automatic differentiation: Forward and backward computational graphs (AOTAutograd)

# %% [markdown]
# TorchDynamo gave us the forward pass function evaluation as an FX graph, but what about the backward pass?

# %%
md('''
# **Forward graph:** $f(x) = sin^2(x)+cos^2(x)$ \n
# **Backward graph:** $\\frac {df(x)}{d\\vec{x}} = f\'(x) = 2sin(x)cos(x) + 2cos(x)(-sin(x))$
''')
# Out:
# # **Forward graph:** $f(x) = sin^2(x)+cos^2(x)$
#
# # **Backward graph:** $\frac {df(x)}{d\vec{x}} = f'(x) = 2sin(x)cos(x) + 2cos(x)(-sin(x))$

# %% [markdown]
# PyTorch uses reverse-mode automatic differentiation to compute the gradients, and PyTorch’s implementation of automation differentiation is called Autograd. PT2 introduces **AOTAutograd** which traces the forward and backward graph ahead of time, i.e. prior to execution, and generates a joint forward and backward graph.
#
# It then partitions the forward and the backward graph into two separate graphs. Both the forward and the backward graphs are stored in the FX graph data structure and can be visualized as shown below.

# %% [markdown]
# We’ll now run AOTAutograd by extending our fake compiler function `inspect_backend` to call AOTAutograd and generate our backward graph. The updated inspect_backed defines a **forward (fw)** and **backward (bw)** compiler capture function that reads the forward and backward graph from AOTAutograd and prints the lowered ATen IR and saves the FX graph for the forward and backward graphs.

# %% [markdown]
# #### AOTAutograd and ATen IR

# %%
import torch._dynamo
from torch.fx.passes.graph_drawer import FxGraphDrawer
from functorch.compile import make_boxed_func
from torch._functorch.aot_autograd import aot_module_simplified

def f(x):
    return torch.sin(x)**2 + torch.cos(x)**2

def inspect_backend(gm, sample_inputs): 
    # Forward compiler capture
    def fw(gm, sample_inputs):
        gm.print_readable()
        print("Notice that sample_inputs is a list of flattened FakeTensor:")
        print(sample_inputs)
        g = FxGraphDrawer(gm, 'fn')
        with open("forward_aot.svg", "wb") as file:
            file.write(g.get_dot_graph().create_svg())
        return make_boxed_func(gm.forward)
    
    # Backward compiler capture
    def bw(gm, sample_inputs):
        gm.print_readable()
        print("Notice that sample_inputs is a list of flattened FakeTensor:")
        print(sample_inputs)
        g = FxGraphDrawer(gm, 'fn')
        with open("backward_aot.svg", "wb") as file:
            file.write(g.get_dot_graph().create_svg())
        return make_boxed_func(gm.forward)
    
    # Call AOTAutograd
    gm_forward = aot_module_simplified(gm,sample_inputs,
                                       fw_compiler=fw,
                                       bw_compiler=bw)

    return gm_forward

torch.manual_seed(0)
x = torch.rand(1000, requires_grad=True).to(device)
y = torch.ones_like(x)

torch._dynamo.reset()
compiled_f = torch.compile(f, backend=inspect_backend)
out = torch.nn.functional.mse_loss(compiled_f(x), y).backward()
# Out:
# _fn(args= (0,), kwargs= {}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$source=LocalSource(local_name='x', cell_or_freevar=False), type(source)=<class 'torch._dynamo.source.LocalSource'>, source.name()="L['x']"$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# _fn(args= (<function create_functionalized_fn.<locals>.joint_helper at 0x7ff9c64f6cb0>,), kwargs= {'tracer': <torch.fx.experimental.proxy_tensor.PythonKeyTracer object at 0x7ff9c65246a0>, 'concrete_args': ([PH], [PH])}
# _fn(args= (<torch.fx.experimental.proxy_tensor.PythonKeyTracer object at 0x7ff9c65246a0>, <function create_functionalized_fn.<locals>.joint_helper at 0x7ff9c64f6cb0>, ([PH], [PH])), kwargs= {}
# class GraphModule(torch.nn.Module):
#     def forward(self, primals_1: "f32[1000]"):
#         # File: /tmp/ipykernel_711820/422412477.py:7 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         sin: "f32[1000]" = torch.ops.aten.sin.default(primals_1)
#         pow_1: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(sin, 2)
#         cos: "f32[1000]" = torch.ops.aten.cos.default(primals_1)
#         pow_2: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(cos, 2)
#         add: "f32[1000]" = torch.ops.aten.add.Tensor(pow_1, pow_2);  pow_1 = pow_2 = None
#         return [add, primals_1, sin, cos]
#
# Notice that sample_inputs is a list of flattened FakeTensor:
# [FakeTensor(..., device='cuda:0', size=(1000,))]
# type(codegen)=<class 'torch._dynamo.codegen.PyCodegen'>, codegen=<torch._dynamo.codegen.PyCodegen object at 0x7ffa875aaf80>
# type(self.guard_manager)=<class 'torch._dynamo.guards.GuardManager'>
# _fn(args= (tensor([4.9626e-01, 7.6822e-01, 8.8477e-02, 1.3203e-01, 3.0742e-01, 6.3408e-01,
#         4.9009e-01, 8.9644e-01, 4.5563e-01, 6.3231e-01, 3.4889e-01, 4.0172e-01,
#         2.2326e-02, 1.6886e-01, 2.9389e-01, 5.1852e-01, 6.9767e-01, 8.0001e-01,
#         1.6103e-01, 2.8227e-01, 6.8161e-01, 9.1519e-01, 3.9710e-01, 8.7416e-01,
#         4.1941e-01, 5.5291e-01, 9.5274e-01, 3.6165e-02, 1.8523e-01, 3.7342e-01,
#         3.0510e-01, 9.3200e-01, 1.7591e-01, 2.6983e-01, 1.5068e-01, 3.1720e-02,
#         2.0813e-01, 9.2980e-01, 7.2311e-01, 7.4234e-01, 5.2630e-01, 2.4366e-01,
#         5.8459e-01, 3.3153e-02, 1.3872e-01, 2.4224e-01, 8.1547e-01, 7.9316e-01,
#         2.7825e-01, 4.8196e-01, 8.1978e-01, 9.9707e-01, 6.9844e-01, 5.6755e-01,
#         8.3524e-01, 2.0560e-01, 5.9317e-01, 1.1235e-01, 1.5346e-01, 2.4171e-01,
#         7.2624e-01, 7.0108e-01, 2.0382e-01, 6.5105e-01, 7.7449e-01, 4.3689e-01,
#         5.1909e-01, 6.1585e-01, 8.1019e-01, 9.8010e-01, 1.1469e-01, 3.1677e-01,
#         6.9650e-01, 9.1427e-01, 9.3510e-01, 9.4118e-01, 5.9951e-01, 6.5209e-02,
#         5.4600e-01, 1.8720e-01, 3.4023e-02, 9.4425e-01, 8.8018e-01, 1.2360e-03,
#         5.9359e-01, 4.1577e-01, 4.1772e-01, 2.7112e-01, 6.9228e-01, 2.0385e-01,
#         6.8330e-01, 7.5285e-01, 8.5794e-01, 6.8696e-01, 5.1324e-03, 1.7565e-01,
#         7.4966e-01, 6.0465e-01, 1.0996e-01, 2.1209e-01, 9.7037e-01, 8.3691e-01,
#         2.8199e-01, 3.7416e-01, 2.3701e-02, 4.9101e-01, 1.2347e-01, 1.1432e-01,
#         4.7245e-01, 5.7507e-01, 2.9523e-01, 7.9669e-01, 1.9573e-01, 9.5369e-01,
#         8.4265e-01, 7.8359e-02, 3.7556e-01, 5.2256e-01, 5.7295e-01, 6.1859e-01,
#         6.9368e-01, 2.8836e-01, 1.9581e-01, 3.0271e-01, 9.1216e-02, 1.0030e-01,
#         7.9919e-01, 7.5412e-01, 5.6660e-01, 2.2687e-01, 6.6635e-01, 5.2246e-01,
#         1.4266e-01, 6.0759e-01, 9.5527e-01, 8.1968e-03, 2.8039e-03, 5.6406e-01,
#         8.7651e-01, 1.9576e-01, 6.1007e-01, 8.5149e-01, 6.5416e-01, 6.0821e-01,
#         9.9886e-01, 8.2574e-01, 2.1879e-01, 5.4322e-01, 7.5544e-01, 9.4095e-01,
#         2.5336e-03, 7.7075e-01, 3.5483e-01, 1.0389e-02, 6.1099e-01, 2.2779e-01,
#         5.7086e-01, 1.7538e-01, 1.2374e-01, 4.5757e-01, 3.3204e-01, 7.9243e-01,
#         5.4311e-01, 8.9028e-01, 5.9370e-01, 3.3922e-01, 8.3867e-01, 5.2732e-01,
#         5.9385e-01, 3.3919e-01, 5.0179e-01, 4.0386e-01], device='cuda:0',
#        grad_fn=<ToCopyBackward0>),), kwargs= {}
# class GraphModule(torch.nn.Module):
#     def forward(self, primals_1: "f32[1000]", sin: "f32[1000]", cos: "f32[1000]", tangents_1: "f32[1000]"):
#         # File: /tmp/ipykernel_711820/422412477.py:7 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         pow_3: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(cos, 1.0);  cos = None
#         mul: "f32[1000]" = torch.ops.aten.mul.Scalar(pow_3, 2.0);  pow_3 = None
#         mul_1: "f32[1000]" = torch.ops.aten.mul.Tensor(tangents_1, mul);  mul = None
#         sin_1: "f32[1000]" = torch.ops.aten.sin.default(primals_1)
#         neg: "f32[1000]" = torch.ops.aten.neg.default(sin_1);  sin_1 = None
#         mul_2: "f32[1000]" = torch.ops.aten.mul.Tensor(mul_1, neg);  mul_1 = neg = None
#         pow_4: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(sin, 1.0);  sin = None
#         mul_3: "f32[1000]" = torch.ops.aten.mul.Scalar(pow_4, 2.0);  pow_4 = None
#         mul_4: "f32[1000]" = torch.ops.aten.mul.Tensor(tangents_1, mul_3);  tangents_1 = mul_3 = None
#         cos_1: "f32[1000]" = torch.ops.aten.cos.default(primals_1);  primals_1 = None
#         mul_5: "f32[1000]" = torch.ops.aten.mul.Tensor(mul_4, cos_1);  mul_4 = cos_1 = None
#
#         # File: /tmp/ipykernel_711820/422412477.py:7 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         add_1: "f32[1000]" = torch.ops.aten.add.Tensor(mul_2, mul_5);  mul_2 = mul_5 = None
#         return [add_1]
#
# Notice that sample_inputs is a list of flattened FakeTensor:
# [FakeTensor(..., device='cuda:0', size=(1000,)), FakeTensor(..., device='cuda:0', size=(1000,)), FakeTensor(..., device='cuda:0', size=(1000,)), FakeTensor(..., device='cuda:0', size=(1000,))]

# %%
md(f'''
|![]({'forward_aot.svg'}) | < Forward graph <br><br><br> Backward graph >|![]({'backward_aot.svg'})|
|---|---|---|
''')
# Out:
# |![](forward_aot.svg) | < Forward graph <br><br><br> Backward graph >|![](backward_aot.svg)|
# |---|---|---|

# %% [markdown]
# The above two graphs with annotations (CHANGE THE PICTURE):
#
#
# | FORWARD GRAPH AOT |  | BACKWARD GRAPH AOT |
# | -------- | -------- | -------- |
# |![image-2.png](attachment:image-2.png) |    | ![image-3.png](attachment:image-3.png)  |

# %% [markdown]
# This will generate the following forward AND backward graphs. Notice that the forward graph also looks slightly different from what we saw earlier. For example `torch.sin(x)` in the FX graph IR and in our original code has been replaced by `torch.ops.aten.sin.default()`.
#
# What’s this funny thing called `aten`, you might ask, if you’re not already familiar with it. **ATen stands for A Tensor library**, which is a very creatively named low level library with a C++ interface that implements many of the fundamental operations that run on CPU and GPU.
#
# In eager mode operation, our PyTorch operations are routed to this library which then calls the appropriate CPU or GPU implementation. **AOTAutograd** automatically generates code that replaces the higher level PyTorch API with **ATen IR** for the forward and backward graph which you can see in the output below:
#
# ```py
# class GraphModule(torch.nn.Module):
#     def forward(self, primals_1: "f32[1000]"):
#         # File: /tmp/ipykernel_702509/422412477.py:7 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         sin: "f32[1000]" = torch.ops.aten.sin.default(primals_1)
#         pow_1: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(sin, 2)
#         cos: "f32[1000]" = torch.ops.aten.cos.default(primals_1)
#         pow_2: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(cos, 2)
#         add: "f32[1000]" = torch.ops.aten.add.Tensor(pow_1, pow_2);  pow_1 = pow_2 = None
#         return [add, primals_1, sin, cos]
# ```
#
# ```py
# class GraphModule(torch.nn.Module):
#     def forward(self, primals_1: "f32[1000]", sin: "f32[1000]", cos: "f32[1000]", tangents_1: "f32[1000]"):
#         # File: /tmp/ipykernel_702509/422412477.py:7 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         pow_3: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(cos, 1.0);  cos = None
#         mul: "f32[1000]" = torch.ops.aten.mul.Scalar(pow_3, 2.0);  pow_3 = None
#         mul_1: "f32[1000]" = torch.ops.aten.mul.Tensor(tangents_1, mul);  mul = None
#         sin_1: "f32[1000]" = torch.ops.aten.sin.default(primals_1)
#         neg: "f32[1000]" = torch.ops.aten.neg.default(sin_1);  sin_1 = None
#         mul_2: "f32[1000]" = torch.ops.aten.mul.Tensor(mul_1, neg);  mul_1 = neg = None
#         pow_4: "f32[1000]" = torch.ops.aten.pow.Tensor_Scalar(sin, 1.0);  sin = None
#         mul_3: "f32[1000]" = torch.ops.aten.mul.Scalar(pow_4, 2.0);  pow_4 = None
#         mul_4: "f32[1000]" = torch.ops.aten.mul.Tensor(tangents_1, mul_3);  tangents_1 = mul_3 = None
#         cos_1: "f32[1000]" = torch.ops.aten.cos.default(primals_1);  primals_1 = None
#         mul_5: "f32[1000]" = torch.ops.aten.mul.Tensor(mul_4, cos_1);  mul_4 = cos_1 = None
#
#         # File: /tmp/ipykernel_702509/422412477.py:7 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         add_1: "f32[1000]" = torch.ops.aten.add.Tensor(mul_2, mul_5);  mul_2 = mul_5 = None
#         return [add_1]
# ```
#
# You can also see that in addition to the output of the forward pass, the forward graph outputs some additional tensors [add, sin, cos, primals_1] . These tensors are saved for the backward pass for gradient calculation.

# %% [markdown]
# ### What are the different types of IR in PyTorch?
# **ATen IR** is a list of operators supported by the ATen library as we discussed in the previous section, and you can see the full list of operations implemented in ATen library.
#
# There are two other IR concepts in PyTorch you should be aware of:
# 1. Core Aten IR
# 2. Prims IR.
#
# Core Aten IR is a subset of the broader Aten IR and Prims IR and an even smaller subset of Core Aten IR.
#
# Let’s say you are designing a processor and want to support PyTorch code acceleration on your hardware. It’d be near impossible to support the full list of PyTorch API in hardware, so what you can do is build a compiler that only supports the smaller subset of fundamental operators defined in Core Aten IR or Prims IR, and let AOTAutograd decompose compound operators into the core operators.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Graph optimization: Layer and operator fusion and C++/GPU code generation

# %% [markdown]
# The computational graph from the output of AOTAutograd in the previous section is composed of many Aten operators represented in an FX graph. TorchInductor optimizations doesn’t change the underlying computation in the graph but merely restructures it with operator and layer fusion, and generates CPU or GPU code for it. Since TorchInductor can see the full forward and backward computational graph ahead of time, it can take decisions on out-of-order execution of operations that don’t have dependence on each other, and maximize hardware resource utilization.
#
# Under the hood, for GPU targets, TorchInductor uses **OpenAI’s Triton** to generate fused GPU kernels. Triton itself is a separate Python based framework and compiler for writing optimized low-level GPU code which is otherwise written in CUDA C/C++. But the only difference is that TorchInductor will generate Triton code which is compiled into low level PTX code.
#
# For multi-core CPU targets, TorchInductor generates C++ code and injects OpenMP pragma directives to generate parallel kernels. From the PyTorch user level world view, this is the IR transformation flow:
#
# ![image.png](attachment:image.png)
#
# Note that TorchInductor takes in inputs in **ATen IR**.

# %% [markdown]
# We’ll now throw away our fake compiler which we used in our previous section, and use the full PyTorch compiler stack that uses TorchInductor.

# %% [markdown]
# RESET IPYNB NOTEBOOK HERE

# %%
import os
os.environ['TORCH_LOGS'] = "+dynamo,guards,bytecode,+inductor"

# %%
import torch
def f(x):
    return torch.sin(x)**2 + torch.cos(x)**2 

torch._dynamo.reset()
compiled_f = torch.compile(f, backend='inductor',
                              options={'trace.enabled':True,
                                       'trace.graph_diagram':True})


# device = 'cpu'
device = 'cuda'

torch.manual_seed(0)
x = torch.rand(1000, requires_grad=True).to(device)
y = torch.ones_like(x)

out = torch.nn.functional.mse_loss(compiled_f(x),y).backward()
# Out:
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0] torchdynamo start compiling f /tmp/ipykernel_711894/2967604626.py:2, stack (elided 6 frames):
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     return _run_code(code, main_globals, None,
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     exec(code, run_globals)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     app.launch_new_instance()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     app.start()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     self.io_loop.start()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     self.asyncio_loop.run_forever()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     self._run_once()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     handle._run()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     self._context.run(self._callback, *self._args)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     await self.process_one()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     await dispatch(*args)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     await result
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     await super().execute_request(stream, ident, parent)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     reply_content = await reply_content
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     res = shell.run_cell(
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     return super().run_cell(*args, **kwargs)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     result = self._run_cell(
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     result = runner(coro)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     coro.send(None)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     if await self.run_code(code, result, async_=asy):
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     exec(code_obj, self.user_global_ns, self.user_ns)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/tmp/ipykernel_711894/2967604626.py", line 18, in <module>
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     out = torch.nn.functional.mse_loss(compiled_f(x),y).backward()
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py", line 421, in _fn
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     return fn(*args, **kwargs)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]   File "/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py", line 1077, in catch_errors
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]     return callback(frame, cache_entry, hooks, frame_state, skip=1)
# V0613 02:05:47.303000 140042118017024 torch/_dynamo/convert_frame.py:758] [0/0]
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode] ORIGINAL BYTECODE f /tmp/ipykernel_711894/2967604626.py line 2
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]   3           0 LOAD_GLOBAL              0 (torch)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               2 LOAD_METHOD              1 (sin)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               4 LOAD_FAST                0 (x)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               6 CALL_METHOD              1
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]               8 LOAD_CONST               1 (2)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              10 BINARY_POWER
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              12 LOAD_GLOBAL              0 (torch)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              14 LOAD_METHOD              2 (cos)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              16 LOAD_FAST                0 (x)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              18 CALL_METHOD              1
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              20 LOAD_CONST               1 (2)
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              22 BINARY_POWER
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              24 BINARY_ADD
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]              26 RETURN_VALUE
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# V0613 02:05:47.305000 140042118017024 torch/_dynamo/convert_frame.py:603] [0/0] [__bytecode]
# I0613 02:05:47.305000 140042118017024 torch/_dynamo/logging.py:55] [0/0] Step 1: torchdynamo start tracing f /tmp/ipykernel_711894/2967604626.py:2
# V0613 02:05:47.306000 140042118017024 torch/fx/experimental/symbolic_shapes.py:2530] [0/0] create_env
# V0613 02:05:47.311000 140042118017024 torch/_dynamo/symbolic_convert.py:771] [0/0] [__trace_source] TRACE starts_line /tmp/ipykernel_711894/2967604626.py:3 in f
# V0613 02:05:47.311000 140042118017024 torch/_dynamo/symbolic_convert.py:771] [0/0] [__trace_source]         return torch.sin(x)**2 + torch.cos(x)**2
# V0613 02:05:47.311000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_GLOBAL torch []
# V0613 02:05:47.313000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_ATTR sin [PythonModuleVariable(<module 'torch' from '/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/__init__.py'>)]
# V0613 02:05:47.315000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_FAST x [TorchInGraphFunctionVariable(<built-in method sin of type object at 0x7f5df367af20>)]
# V0613 02:05:47.315000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [TorchInGraphFunctionVariable(<built-in method sin of type object at 0x7f5df367af20>), LazyVariableTracker()]
# V0613 02:05:47.316000 140042118017024 torch/_dynamo/output_graph.py:2029] [0/0] create_graph_input L_x_ L['x']
# V0613 02:05:47.317000 140042118017024 torch/_dynamo/variables/builder.py:2277] [0/0] wrap_to_fake L['x'] (1000,) StatefulSymbolicContext(dynamic_sizes=[<DimDynamic.STATIC: 2>], constraint_sizes=[None], view_base_context=None, tensor_source=LocalSource(local_name='x', cell_or_freevar=False), shape_env_to_source_to_symbol_cache={}) <class 'torch.Tensor'>
# V0613 02:05:47.321000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_CONST 2 [TensorVariable()]
# V0613 02:05:47.321000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE BINARY_POWER None [TensorVariable(), ConstantVariable()]
# V0613 02:05:47.323000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_GLOBAL torch [TensorVariable()]
# V0613 02:05:47.323000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_ATTR cos [TensorVariable(), PythonModuleVariable(<module 'torch' from '/media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/__init__.py'>)]
# V0613 02:05:47.324000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_FAST x [TensorVariable(), TorchInGraphFunctionVariable(<built-in method cos of type object at 0x7f5df367af20>)]
# V0613 02:05:47.324000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE CALL_FUNCTION 1 [TensorVariable(), TorchInGraphFunctionVariable(<built-in method cos of type object at 0x7f5df367af20>), TensorVariable()]
# V0613 02:05:47.326000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE LOAD_CONST 2 [TensorVariable(), TensorVariable()]
# V0613 02:05:47.326000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE BINARY_POWER None [TensorVariable(), TensorVariable(), ConstantVariable()]
# V0613 02:05:47.327000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE BINARY_ADD None [TensorVariable(), TensorVariable()]
# V0613 02:05:47.328000 140042118017024 torch/_dynamo/symbolic_convert.py:794] [0/0] [__trace_bytecode] TRACE RETURN_VALUE None [TensorVariable()]
# I0613 02:05:47.329000 140042118017024 torch/_dynamo/logging.py:55] [0/0] Step 1: torchdynamo done tracing f (RETURN_VALUE)
# V0613 02:05:47.329000 140042118017024 torch/_dynamo/symbolic_convert.py:2419] [0/0] RETURN_VALUE triggered compile
# V0613 02:05:47.330000 140042118017024 torch/_dynamo/output_graph.py:971] [0/0] COMPILING GRAPH due to GraphCompileReason(reason='return_value', user_stack=[<FrameSummary file /tmp/ipykernel_711894/2967604626.py, line 3 in f>], graph_break=False)
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code] TRACED GRAPH
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]  ===== __compiled_fn_1 =====
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]  /media/abhishek/Abhishek_NVMe/shweta_machine/trace_analysis/pytorch-venv-front-end/lib/python3.10/site-packages/torch/fx/_lazy_graph_module.py class GraphModule(torch.nn.Module):
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]     def forward(self, L_x_: "f32[1000]"):
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         l_x_ = L_x_
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         # File: /tmp/ipykernel_711894/2967604626.py:3 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         sin: "f32[1000]" = torch.sin(l_x_)
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         pow_1: "f32[1000]" = sin ** 2;  sin = None
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         cos: "f32[1000]" = torch.cos(l_x_);  l_x_ = None
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         pow_2: "f32[1000]" = cos ** 2;  cos = None
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         add: "f32[1000]" = pow_1 + pow_2;  pow_1 = pow_2 = None
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]         return (add,)
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]
# V0613 02:05:47.332000 140042118017024 torch/_dynamo/output_graph.py:1290] [0/0] [__graph_code]
# I0613 02:05:47.333000 140042118017024 torch/_dynamo/logging.py:55] [0/0] Step 2: calling compiler function inductor
# _fn(args= (0,), kwargs= {}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$source=LocalSource(local_name='x', cell_or_freevar=False), type(source)=<class 'torch._dynamo.source.LocalSource'>, source.name()="L['x']"$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# opcode         name    target                                                  args            kwargs    meta
# -------------  ------  ------------------------------------------------------  --------------  --------  ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# placeholder    l_x_    L_x_                                                    ()              {}        {'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<Error>), 'tensor_dict': {}, 'grapharg': GraphArg(source=LocalSource(local_name='x', cell_or_freevar=False), _example=<torch.utils.weak.TensorWeakRef object at 0x7f5d361f6050>, pass_arg_as_tensor=False, fake_tensor=FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<Error>), is_tensor=True, example_strong_ref=None)}
# call_function  sin     <built-in method sin of type object at 0x7f5df367af20>  (l_x_,)         {}        {'source_fn_stack': [('sin', <built-in method sin of type object at 0x7f5df367af20>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<SinBackward0>)}
# call_function  pow_1   <built-in function pow>                                 (sin, 2)        {}        {'source_fn_stack': [('pow_1', <built-in function pow>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<PowBackward0>)}
# call_function  cos     <built-in method cos of type object at 0x7f5df367af20>  (l_x_,)         {}        {'source_fn_stack': [('cos', <built-in method cos of type object at 0x7f5df367af20>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<CosBackward0>)}
# call_function  pow_2   <built-in function pow>                                 (cos, 2)        {}        {'source_fn_stack': [('pow_2', <built-in function pow>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<PowBackward0>)}
# call_function  add     <built-in function add>                                 (pow_1, pow_2)  {}        {'source_fn_stack': [('add', <built-in function add>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<AddBackward0>)}
# output         output  output                                                  ((add,),)       {}        {'creation_timestamp': 0}
# class GraphModule(torch.nn.Module):
#     def forward(self, L_x_: "f32[1000]"):
#         l_x_ = L_x_
#
#         # File: /tmp/ipykernel_711894/2967604626.py:3 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         sin: "f32[1000]" = torch
device='cuda:0',
#        grad_fn=<ToCopyBackward0>)]
# opcode         name    target                                                  args            kwargs    meta
# -------------  ------  ------------------------------------------------------  --------------  --------  ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# placeholder    l_x_    L_x_                                                    ()              {}        {'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<Error>), 'tensor_dict': {}, 'grapharg': GraphArg(source=LocalSource(local_name='x', cell_or_freevar=False), _example=<torch.utils.weak.TensorWeakRef object at 0x7f5d361f6050>, pass_arg_as_tensor=False, fake_tensor=FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<Error>), is_tensor=True, example_strong_ref=None)}
# call_function  sin     <built-in method sin of type object at 0x7f5df367af20>  (l_x_,)         {}        {'source_fn_stack': [('sin', <built-in method sin of type object at 0x7f5df367af20>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<SinBackward0>)}
# call_function  pow_1   <built-in function pow>                                 (sin, 2)        {}        {'source_fn_stack': [('pow_1', <built-in function pow>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<PowBackward0>)}
# call_function  cos     <built-in method cos of type object at 0x7f5df367af20>  (l_x_,)         {}        {'source_fn_stack': [('cos', <built-in method cos of type object at 0x7f5df367af20>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<CosBackward0>)}
# call_function  pow_2   <built-in function pow>                                 (cos, 2)        {}        {'source_fn_stack': [('pow_2', <built-in function pow>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<PowBackward0>)}
# call_function  add     <built-in function add>                                 (pow_1, pow_2)  {}        {'source_fn_stack': [('add', <built-in function add>)], 'stack_trace': '  File "/tmp/ipykernel_711894/2967604626.py", line 3, in f\n    return torch.sin(x)**2 + torch.cos(x)**2\n', 'example_value': FakeTensor(..., device='cuda:0', size=(1000,), grad_fn=<AddBackward0>)}
# output         output  output                                                  ((add,),)       {}        {'creation_timestamp': 0}
# class GraphModule(torch.nn.Module):
#     def forward(self, L_x_: "f32[1000]"):
#         l_x_ = L_x_
#
#         # File: /tmp/ipykernel_711894/2967604626.py:3 in f, code: return torch.sin(x)**2 + torch.cos(x)**2
#         sin: "f32[1000]" = torch.sin(l_x_)
#         pow_1: "f32[1000]" = sin ** 2;  sin = None
#         cos: "f32[1000]" = torch.cos(l_x_);  l_x_ = None
#         pow_2: "f32[1000]" = cos ** 2;  cos = None
#         add: "f32[1000]" = pow_1 + pow_2;  pow_1 = pow_2 = None
#         return (add,)
#
# example_inputs_=[tensor([4.9626e-01, 7.6822e-01, 8.8477e-02, 1.3203e-01, 3.0742e-01, 6.3408e-01,
#         4.9009e-01, 8.9644e-01, 4.5563e-01, 6.3231e-01, 3.4889e-01, 4.0172e-01,
#         2.2326e-02, 1.6886e-01, 2.9389e-01, 5.1852e-01, 6.9767e-01, 8.0001e-01,
#         1.6103e-01, 2.8227e-01, 6.8161e-01, 9.1519e-01, 3.9710e-01, 8.7416e-01,
#         4.1941e-01, 5.5291e-01, 9.5274e-01, 3.6165e-02, 1.8523e-01, 3.7342e-01,
#         3.0510e-01, 9.3200e-01, 1.7591e-01, 2.6983e-01, 1.5068e-01, 3.1720e-02,
#         2.0813e-01, 9.2980e-01, 7.2311e-01, 7.4234e-01, 5.2630e-01, 2.4366e-01,
#         7.9919e-01, 7.5412e-01, 5.6660e-01, 2.2687e-01, 6.6635e-01, 5.2246e-01,
#         1.4266e-01, 6.0759e-01, 9.5527e-01, 8.1968e-03, 2.8039e-03, 5.6406e-01,
#         8.7651e-01, 1.9576e-01, 6.1007e-01, 8.5149e-01, 6.5416e-01, 6.0821e-01,
#         9.9886e-01, 8.2574e-01, 2.1879e-01, 5.4322e-01, 7.5544e-01, 9.4095e-01,
#         2.5336e-03, 7.7075e-01, 3.5483e-01, 1.0389e-02, 6.1099e-01, 2.2779e-01,
#         5.7086e-01, 1.7538e-01, 1.2374e-01, 4.5757e-01, 3.3204e-01, 7.9243e-01,
#         5.4311e-01, 8.9028e-01, 5.9370e-01, 3.3922e-01, 8.3867e-01, 5.2732e-01,
#         5.9385e-01, 3.3919e-01, 5.0179e-01, 4.0386e-01], device='cuda:0',
#        grad_fn=<ToCopyBackward0>), tensor([ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#         -1.1921e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  2.3842e-10,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00, -1.1921e-10,  0.0000e+00, -1.1921e-10,
#          2.3842e-10,  2.3842e-10,  2.3842e-10,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          2.3842e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00, -1.1921e-10,
#         -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,
#          0.0000e+00, -1.1921e-10,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  2.3842e-10, -1.1921e-10,  2.3842e-10, -1.1921e-10,
#          0.0000e+00,  2.3842e-10,  2.3842e-10,  0.0000e+00, -1.1921e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00, -1.1921e-10, -1.1921e-10,  2.3842e-10,  2.3842e-10,
#          0.0000e+00,  2.3842e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  2.3842e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,  2.3842e-10,
#          2.3842e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,
#         -1.1921e-10, -1.1921e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10, -1.1921e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,
#          2.3842e-10,  2.3842e-10,  0.0000e+00,  2.3842e-10, -1.1921e-10,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,  0.0000e+00,
#         -1.1921e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  2.3842e-10,  0.0000e+00, -1.1921e-10,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  2.3842e-10,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00, -1.1921e-10, -1.1921e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00, -1.1921e-10,  0.0000e+00,  2.3842e-10,
#          0.0000e+00, -1.1921e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10, -1.1921e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00, -1.1921e-10, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#         -1.1921e-10,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,
#         -1.1921e-10,  0.0000e+00,  2.3842e-10, -1.1921e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00, -1.1921e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10, -1.1921e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00, -1.1921e-10,
#          2.3842e-10,  0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          2.3842e-10, -1.1921e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,
#          2.3842e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  2.3842e-10,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          2.3842e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  2.3842e-10,  2.3842e-10,  2.3842e-10,  0.0000e+00,
#          2.3842e-10,  0.0000e+00,  2.3842e-10,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10, -1.1921e-10,
#          0.0000e+00,  2.3842e-10,  2.3842e-10,  2.3842e-10,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,  2.3842e-10,
#         -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#          0.0000e+00, -1.1921e-10,  2.3842e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  2.3842e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  0.0000e+00, -1.1921e-10,  0.0000e+00,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,
#          0.0000e+00,  2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          0.0000e+00,  0.0000e+00,  0.0000e+00, -1.1921e-10,  0.0000e+00,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#         -1.1921e-10,  0.0000e+00,  0.0000e+00,  0.0000e+00,  2.3842e-10,
#          2.3842e-10,  0.0000e+00,  0.0000e+00,  2.3842e-10,  0.0000e+00],
#        device='cuda:0')]

# %%
from IPython.display import Markdown as md
import glob
fwd = glob.glob('torch_compile_debug/run_*/*torchinductor/*forward*/graph_diagram.svg')[-1]
bwd = glob.glob('torch_compile_debug/run_*/*torchinductor/*backward*/graph_diagram.svg')[-1]

md(f'''
|![]({fwd}) | < Forward graph <br><br><br> Backward graph >|![]({bwd})|
|---|---|---|
''')
# Out:
# |![](torch_compile_debug/run_2024_06_13_02_05_47_751315-pid_711894/torchinductor/model__0_forward_1.0/graph_diagram.svg) | < Forward graph <br><br><br> Backward graph >|![](torch_compile_debug/run_2024_06_13_02_05_47_751315-pid_711894/torchinductor/model__0_backward_3.1/graph_diagram.svg)|
# |---|---|---|

# %% [markdown]
# This is how the operators are fused in Torch Inductor from the Aten IR:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Define-By-Run Loop Level IR (TorchInductor IR)

# %% [markdown]
# In the above debug logs we some code as follows for the foward graph:
# ```py
#  scheduling ComputedBuffer(name='buf0', layout=FixedLayout('cuda', torch.float32, size=[1000], stride=[1]), data=Pointwise(
#    'cuda',
#    torch.float32,
#    def inner_fn(index):
#        i0 = index
#        tmp0 = ops.load(primals_1, i0)
#        tmp1 = ops.sin(tmp0)
#        tmp2 = tmp1 * tmp1
#        tmp3 = ops.load(primals_1, i0)
#        tmp4 = ops.cos(tmp3)
#        tmp5 = tmp4 * tmp4
#        tmp6 = tmp2 + tmp5
#        return tmp6
#    ,
#    ranges=[1000],
#    origin_node=add,
#    origins={pow_1, sin, cos, add, pow_2}
#  ))
# ```
#
# The Aten IR which TorchInductor gets as input is used to generate this above define-by-run loop level run. The operations mentioned in the ATen IR are lowered to the torch inductor "ops.*".
#
# The function definition `inner_fn` shown above is used to populate each elment of the output buffer, using a loop.
#
# The `range` above having a value `1000` shows that this function shall be used interally 1000 times in a loop to generate each of the 1000 elements.
#
# Certain layout decisions are also made in a approach called `scheduling`.
#
# The above TorchInductor IR is called "Define-By-Run" because the "ops" are overloaded in different passes to perform different operations. For example "ops" may be overloaded to a some kind which is useful for doing operator fusion. While, again, the "ops" can be overloaded to something like "codegen" to do the codegen.
#
# A comparison of the output triton forward graph codegen with the DBR-IR:
# ```py
# triton_poi_fused_add_cos_pow_sin_0 = async_compile.triton('triton_', '''
# import triton
# import triton.language as tl
# from triton.compiler.compiler import AttrsDescriptor
#
# from torch._inductor.runtime import triton_helpers, triton_heuristics
# from torch._inductor.runtime.triton_helpers import libdevice, math as tl_math
# from torch._inductor.runtime.hints import AutotuneHint, ReductionHint, TileHint, instance_descriptor, DeviceProperties
#
# @triton_heuristics.pointwise(
#     size_hints=[1024],
#     filename=__file__,
#     triton_meta={'signature': {0: '*fp32', 1: '*fp32', 2: 'i32'}, 'device': DeviceProperties(type='cuda', index=0, cc=75, major=7, regs_per_multiprocessor=65536, max_threads_per_multi_processor=1024, multi_processor_count=46), 'constants': {}, 'configs': [AttrsDescriptor(divisible_by_16=(0, 1), equal_to_1=())]},
#     inductor_meta={'autotune_hints': set(), 'kernel_name': 'triton_poi_fused_add_cos_pow_sin_0', 'mutated_arg_names': [], 'no_x_dim': False, 'num_load': 1, 'num_reduction': 0, 'backend_hash': '6e95335dfe32e7159670fdd0127b9a4b9aafe61a035a1d09d747878c52d0b360', 'are_deterministic_algorithms_enabled': False, 'assert_indirect_indexing': True, 'autotune_local_cache': True, 'autotune_pointwise': True, 'autotune_remote_cache': False, 'force_disable_caches': False, 'dynamic_scale_rblock': True, 'max_autotune': False, 'max_autotune_pointwise': False, 'min_split_scan_rblock': 256, 'spill_threshold': 16, 'store_cubin': False},
#     min_elem_per_thread=0
# )
# @triton.jit
# def triton_(in_ptr0, out_ptr0, xnumel, XBLOCK : tl.constexpr):
#     xnumel = 1000
#     xoffset = tl.program_id(0) * XBLOCK
#     xindex = xoffset + tl.arange(0, XBLOCK)[:]
#     xmask = xindex < xnumel
#     x0 = xindex
#     tmp0 = tl.load(in_ptr0 + (x0), xmask)
#     tmp1 = tl_math.sin(tmp0)
#     tmp2 = tmp1 * tmp1
#     tmp3 = tl_math.cos(tmp0)
#     tmp4 = tmp3 * tmp3
#     tmp5 = tmp2 + tmp4
#     tl.store(out_ptr0 + (x0), tmp5, xmask)
# ''', device_str='cuda')
# ```

# %% [markdown]
# Comparision of the Inductor IR code with Output Triton Codegen
#
# ![image.png](attachment:image.png)
